# %%
# conda install git

# %%
# pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
import numpy as np
import pandas as pd
import twint
import time
from datetime import datetime

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', 199)
pd.options.display.float_format = '{:.2f}'.format

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import nltk
from nltk.tokenize import ToktokTokenizer
toktok = ToktokTokenizer()
from nltk.corpus import stopwords
# lemma = nltk.wordnet.WordNetLemmatizer()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\crackcocaine69xxx\AppData\Roaming\nltk_data..
# [nltk_data]     .
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = set(stopwords.words("english"))
stopwords -= {'who'}
stopwords.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}']) # remove it if you need punctuation

# %%
def remove_junk_from_str(string):
    return " ".join([x for x in toktok.tokenize(string) if x.lower() not in stopwords and x[0]!='#' and x[:3]!='htt'])

vec_remove_junk = np.vectorize(remove_junk_from_str)

# %%
def clean_tweets(df):
    local_df = df
    
    #drop redundant cols
    local_df.drop(['created_at', 'timezone', 'language', 'cashtags', 'user_id_str', 'urls', 'photos', 'video', 'thumbnail', 'translate', 'trans_src', 'trans_dest', 'name', 'search'], axis=1, inplace=True)
    
    #convert date to datetime
    local_df['date'] = pd.to_datetime(local_df['date'])
    
    #REMOVE STOPWORDS FROM TWEET HERE
    local_df['tweet'] = list(map(vec_remove_junk, local_df['tweet']))
    
    return local_df

# %% [markdown]
# ## Collect Tweets hashtags

# %% [markdown]
# ## Fetch tweets within a date range

# %%
def find_tweets_in_date_range(search_terms, start_date, end_date):
    '''    
    search_terms = list of strings (or singleton) of search terms that will be in the tweet
    
    returns a pandas dataframe of tweets
    '''
    
    search_string = " OR ".join(search_terms)
    
    c = twint.Config()
    
#     date range of search
    c.Since = start_date
    c.Until = end_date
    
    c.Search = search_string
    
    # only collect a certain number of tweets
#     c.Limit = num_tweets

    # Don't print output
    c.Hide_output = True
    
    # find shadow-banned accounts too - this apparently slows things down considerably
    c.Profile_full = True

#     c.Output = f"{num_tweets} tweets - {start_date} to {end_date}.csv"
    c.Pandas = True

    twint.run.Search(c)

#     tweets_df = twint.storage.panda.Tweets_df
    
#     return clean_tweets(tweets_df)

    clean_tweets(twint.storage.panda.Tweets_df).to_csv(fr"C:/Users/crackcocaine69xxx/Python Stuff/594/Twint/Twint Output{start_date} to {end_date}.csv")

# %% [markdown]
# ### Fetch tweets up to a number limit

# %%
def find_tweets_by_limit(num_tweets, search_terms):#, start_date, end_date):
    '''    
    search_terms = list of strings (or singleton) of search terms that will be in the tweet
    
    returns a pandas dataframe
    '''
    
    search_string = " OR ".join(search_terms)
    
    c = twint.Config()
    
    # date range of search
#     c.Since = start_date
#     c.Until = end_date
    
    c.Search = search_string
    
    # only collect a certain number of tweets
    c.Limit = num_tweets

    # Don't print output
    c.Hide_output = True
    
    # find shadow-banned accounts too - this apparently slows things down considerably
    c.Profile_full = True

#     c.Output = f"{num_tweets} tweets - {start_date} to {end_date}.csv"
    c.Pandas = True

    twint.run.Search(c)

    tweets_df = twint.storage.panda.Tweets_df
    
    return clean_tweets(tweets_df)

# %% [markdown]
# ## Find most common associated hashtags

# %%
def find_associated_hashtags(series):
    '''
    series = pd series where each observation is a python list
    '''
    hashtag_set = set([tag for list_of_tags in series for tag in list_of_tags])
    
    
    count_dict = dict.fromkeys(hashtag_set, 0)
    for list_of_tags in series:
        for tag in list_of_tags:
            count_dict[tag] += 1

    count_dict = dict(sorted(count_dict.items(), key=lambda item: item[1], reverse=True))

    
    return(count_dict)

# %% [markdown]
# ## List of Hashtags to Search

# %%
# conspiracy_hashtags is a list of hashtags that I think are used by people who don't believe that covid is real (or who belive that it's overblown).
# Note that there are conspiracy theorists who believe it does exist but was intentionally planted by china etc. these are not the conspiracy theorists I want!!!

#SHOULD I TRY TO SEPARATE THE TWO GROUPS? THEY MIGHT NOT EVEN BE SEPARATE???

general_conspiracy_hashtags = [
    'plandemic',
    'scamdemic',
    'covidhoax',
    'nwo',
    'covid1984',
    'plandemia',
    'agenda21',
    'thegreatreset',
    'agenda2030',
    'newworldorder',
    'wakeupamerica',
    'wakeup',
    'openamericanow',
    'firefauci',
    'wwg1wga',
    'qanon',
    'coronahoax'
]

general_conspiracy_hashtags = general_conspiracy_hashtags + [f'#{x}' for x in general_conspiracy_hashtags]

# covid_denier_hashtags = [
#     'plandemic',
#     'scamdemic',
#     'covidhoax',    
# ]

# %% [markdown]
# ## Loop to find all tweets

# %% [markdown]
# ### Create Date Ranges

# %%
from datetime import timedelta, date

# %%
week = timedelta(weeks=1)
sixdays = timedelta(days=6)

# %%
date_ranges = []

today_str = date.today().strftime('%d-%m-%Y')

for date in pd.date_range(start='1-1-2020', end=today_str, freq='1W'):
    date_tuple = ((date.strftime('%Y-%m-%d'), (date+sixdays).strftime('%Y-%m-%d') ))
    
    print(date_tuple, '\n')
    
    date_ranges.append(date_tuple)
    
# date_ranges
# Out:
# ('2020-01-05', '2020-01-11')
#
# ('2020-01-12', '2020-01-18')
#
# ('2020-01-19', '2020-01-25')
#
# ('2020-01-26', '2020-02-01')
#
# ('2020-02-02', '2020-02-08')
#
# ('2020-02-09', '2020-02-15')
#
# ('2020-02-16', '2020-02-22')
#
# ('2020-02-23', '2020-02-29')
#
# ('2020-03-01', '2020-03-07')
#
# ('2020-03-08', '2020-03-14')
#
# ('2020-03-15', '2020-03-21')
#
# ('2020-03-22', '2020-03-28')
#
# ('2020-03-29', '2020-04-04')
#
# ('2020-04-05', '2020-04-11')
#
# ('2020-04-12', '2020-04-18')
#
# ('2020-04-19', '2020-04-25')
#
# ('2020-04-26', '2020-05-02')
#
# ('2020-05-03', '2020-05-09')
#
# ('2020-05-10', '2020-05-16')
#
# ('2020-05-17', '2020-05-23')
#
# ('2020-05-24', '2020-05-30')
#
# ('2020-05-31', '2020-06-06')
#
# ('2020-06-07', '2020-06-13')
#
# ('2020-06-14', '2020-06-20')
#
# ('2020-06-21', '2020-06-27')
#
# ('2020-06-28', '2020-07-04')
#
# ('2020-07-05', '2020-07-11')
#
# ('2020-07-12', '2020-07-18')
#
# ('2020-07-19', '2020-07-25')
#
# ('2020-07-26', '2020-08-01')
#
# ('2020-08-02', '2020-08-08')
#
# ('2020-08-09', '2020-08-15')
#
# ('2020-08-16', '2020-08-22')
#
# ('2020-08-23', '2020-08-29')
#
# ('2020-08-30', '2020-09-05')
#
# ('2020-09-06', '2020-09-12')
#
# ('2020-09-13', '2020-09-19')
#
# ('2020-09-20', '2020-09-26')
#
# ('2020-09-27', '2020-10-03')
#
# ('2020-10-04', '2020-10-10')
#
# ('2020-10-11', '2020-10-17')
#
# ('2020-10-18', '2020-10-24')
#
# ('2020-10-25', '2020-10-31')
#
# ('2020-11-01', '2020-11-07')
#
# ('2020-11-08', '2020-11-14')
#
# ('2020-11-15', '2020-11-21')
#
# ('2020-11-22', '2020-11-28')
#
# ('2020-11-29', '2020-12-05')
#
# ('2020-12-06', '2020-12-12')
#
# ('2020-12-13', '2020-12-19')
#
# ('2020-12-20', '2020-12-26')
#
# ('2020-12-27', '2021-01-02')
#
# ('2021-01-03', '2021-01-09')
#
# ('2021-01-10', '2021-01-16')
#
# ('2021-01-17', '2021-01-23')
#
# ('2021-01-24', '2021-01-30')
#
# ('2021-01-31', '2021-02-06')
#
# ('2021-02-07', '2021-02-13')
#
# ('2021-02-14', '2021-02-20')
#
# ('2021-02-21', '2021-02-27')
#
# ('2021-02-28', '2021-03-06')
#
# ('2021-03-07', '2021-03-13')
#
# ('2021-03-14', '2021-03-20')
#
# ('2021-03-21', '2021-03-27')
#
# ('2021-03-28', '2021-04-03')
#
# ('2021-04-04', '2021-04-10')
#
# ('2021-04-11', '2021-04-17')
#
# ('2021-04-18', '2021-04-24')
#
# ('2021-04-25', '2021-05-01')
#
# ('2021-05-02', '2021-05-08')
#
# ('2021-05-09', '2021-05-15')
#
# ('2021-05-16', '2021-05-22')
#
# ('2021-05-23', '2021-05-29')

# %% [markdown]
# ## Final Loop

# %%
for date_tuple in date_ranges:
    find_tweets_in_date_range(general_conspiracy_hashtags, date_tuple[0], date_tuple[1])
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
find_tweets_in_date_range(general_conspiracy_hashtags, '2021-05-23', '2021-05-29')

# %%
mask_tweets_100k = find_tweets_by_limit(100000, ['mask'])

# %% [markdown]
# ## Trash

# %% [markdown]
# ### Make "general_conspiracy_400k"

# %%
general_conspiracy_400k = find_tweets_by_limit(400000, general_conspiracy_hashtags)

# %%
general_conspiracy_400k.to_csv(r"400k Conspiracy Tweets.csv", index=False)

# %%
find_associated_hashtags(general_conspiracy_400k['hashtags'])
# Out:
# {'wakeup': 85607,
#  'agenda2030': 53037,
#  'plandemia': 51217,
#  'thegreatreset': 47530,
#  'nwo': 43913,
#  'wakeupamerica': 37713,
#  'plandemic': 28670,
#  'scamdemic': 27545,
#  'covid19': 26953,
#  'covid1984': 26680,
#  'newworldorder': 17401,
#  'agenda21': 13270,
#  'greatreset': 11285,
#  'covid': 10442,
#  'immusic': 9620,
#  'buildbackbetter': 9353,
#  'covidhoax': 8718,
#  'ods': 6956,
#  'wef': 6822,
#  'coronavirus': 6340,
#  'truth': 6018,
#  'maga': 4915,
#  'lockdown': 4546,
#  'freedom': 3967,
#  'vaccine': 3857,
#  'covid_19': 3760,
#  'yonomevacuno': 3479,
#  'klausschwab': 3275,
#  'sdgs': 3116,
#  'coronatimo': 3103,
#  'votefraud': 2940,
#  'america': 2874,
#  'trump': 2866,
#  'noalbozal': 2710,
#  'usa': 2680,
#  'billgates': 2447,
#  'news': 2282,
#  'crimesagainsthumanity': 2249,
#  'corona': 2239,
#  'enoughisenough': 2220,
#  'covidvaccine': 2216,
#  'noalavacuna': 2162,
#  'elections': 2081,
#  'china': 2071,
#  'electionresults2020': 2057,
#  'thefirstontv': 2037,
#  'plandemie': 1999,
#  'genocidio': 1995,
#  'biden': 1992,
#  'prepper': 1978,
#  'laverdadesunasola': 1956,
#  'illuminati': 1907,
#  'noalnuevoordenmundial': 1899,
#  'goodmorning': 1886,
#  'coronafarsa': 1880,
#  'dictadurasanitaria': 1872,
#  'covidianos': 1813,
#  'nom': 1794,
#  'tyranny': 1778,
#  'god': 1772,
#  'canada': 1746,
#  'covidー19': 1744,
#  'vaccines': 1744,
#  'prepping': 1725,
#  'borregos': 1720,
#  'noalamascarillaobligatoria': 1690,
#  'deepstate': 1686,
#  'fakenews': 1682,
#  'jesus': 1676,
#  'anonymous': 1675,
#  'noalconfinamiento': 1666,
#  'periodistascobardes': 1655,
#  'sanitariosasesinos': 1655,
#  'políticosaprisión': 1655,
#  'rebrotetimo': 1653,
#  'pandemic': 1636,
#  'covidiots': 1591,
#  'stopthesteal': 1575,
#  'worldeconomicforum': 1503,
#  'mividamioxigeno': 1480,
#  'who': 1474,
#  'msm': 1462,
#  'bigpharma': 1452,
#  'event201': 1450,
#  'world': 1448,
#  'terrorismoinformativo': 1433,
#  'kbf': 1431,
#  'un': 1423,
#  'peertube': 1417,
#  'depopulation': 1404,
#  'vaccination': 1379,
#  'democrats': 1347,
#  'corruption': 1339,
#  'breakingnews': 1336,
#  'falsapandemia': 1319,
#  'circovid': 1311,
#  'wethepeople': 1291,
#  'bitcoin': 1274,
#  'propaganda': 1268,
#  'fightback': 1261,
#  'slr': 1245,
#  'globalgoals': 1234,
#  'eu': 1226,
#  'novaccinepassports': 1212,
#  'wef21': 1202,
#  'elpulitzertampoco': 1201,
#  'censorship': 1181,
#  'pandemia': 1162,
#  'morning': 1141,
#  'politics': 1133,
#  'sostenibilidad': 1127,
#  'psyop': 1114,
#  'realnews': 1107,
#  'coronamaatregelen': 1104,
#  'nomasks': 1103,
#  'covid19vaccine': 1102,
#  'newsupdate': 1098,
#  'newnormal': 1094,
#  'hoax': 1093,
#  'zajob': 1092,
#  'communism': 1071,
#  'odd': 1070,
#  'desarrollosostenible': 1066,
#  'davosagenda': 1059,
#  'breaking': 1058,
#  'ccp': 1034,
#  'wwe': 1033,
#  'cdnpoli': 1031,
#  'freepalestine': 1030,
#  'ourinterestingtimes': 1021,
#  'fightfortrump': 1019,
#  'pfizer': 1010,
#  'punked': 1003,
#  'blm': 986,
#  'nuevoordenmundial': 983,
#  'genocide': 969,
#  'sheeple': 965,
#  'covidiotas': 962,
#  'noalnom': 962,
#  'love': 960,
#  'uk': 958,
#  'lockdowns': 945,
#  'justsayno': 930,
#  'vaccinepassports': 927,
#  'resist': 922,
#  'joebiden': 903,
#  'rutte': 901,
#  'pcrgate': 888,
#  'bigtech': 887,
#  'wcw': 882,
#  'gazaunderattack': 877,
#  'pcr': 875,
#  'deceived': 869,
#  'infowar': 869,
#  'globalists': 868,
#  'virus': 865,
#  'climatechange': 863,
#  'scamdemic2020': 863,
#  'masks': 863,
#  'davos': 861,
#  'lord': 859,
#  'endtimes': 857,
#  'tcot': 855,
#  'health': 854,
#  'name': 851,
#  'yahuah': 850,
#  'testeverything': 848,
#  'yahusha': 848,
#  'whole': 848,
#  'economy': 839,
#  'vacunacovid19': 832,
#  'standup': 832,
#  'americafirst': 829,
#  'bible': 825,
#  'soros': 822,
#  'conservatives': 821,
#  'newsalert': 818,
#  'podcast': 815,
#  'endthelockdown': 813,
#  'covidsecondwave': 813,
#  'id2020': 812,
#  'casedemic': 797,
#  'coffee': 790,
#  'concernedhighhorse': 777,
#  'chinavirus': 776,
#  'desobedienciacivil': 775,
#  'onu': 773,
#  'thegreatresist': 767,
#  'lies': 762,
#  'agenda': 762,
#  'fauci': 752,
#  'depopulationagenda': 751,
#  'dictadura': 750,
#  'stemzeweg': 744,
#  'freespeech': 738,
#  'novaccineforme': 730,
#  'billgatesbioterrorist': 714,
#  'control': 712,
#  'endthelockdowns': 711,
#  'scamdemic2021': 710,
#  'despierta': 705,
#  'policestate': 702,
#  'infectadura': 701,
#  'españa': 698,
#  'onpoli': 697,
#  'liberty': 696,
#  'thegreatawakening': 692,
#  'tlot': 688,
#  'nomorelockdowns': 685,
#  'bbb': 682,
#  'treason': 680,
#  'woke': 677,
#  'fraud': 676,
#  'humanrights': 675,
#  'democratsaredestroyingamerica': 674,
#  'libertad': 673,
#  'socialism': 673,
#  'win': 672,
#  'amazon': 668,
#  'nonewnormal': 667,
#  'covid19nl': 667,
#  '5g': 663,
#  'toronto': 661,
#  'mpk': 649,
#  'leavenoonebehind': 646,
#  'bilderberg': 640,
#  'music': 638,
#  'youtube': 632,
#  'nuremberg2': 627,
#  'riseup': 626,
#  'merkel': 623,
#  'masksdontwork': 622,
#  'democracy': 618,
#  'covid19india': 616,
#  'maskoff': 611,
#  'chile': 610,
#  'mindcontrol': 605,
#  'nazi': 605,
#  'climateaction': 605,
#  'quotes': 604,
#  'russia': 601,
#  'astrazeneca': 597,
#  'israel': 595,
#  'media': 595,
#  'reset': 594,
#  'coronacirco': 590,
#  'ahora': 586,
#  'globalreset': 583,
#  'klaarmetrutte': 583,
#  'novaccinepassportsanywhere': 578,
#  'covid19uk': 577,
#  'conspiracy': 575,
#  'republicans': 573,
#  'nieszczepimysie': 570,
#  'elitesdgs': 567,
#  'trump2020': 563,
#  'walkaway': 563,
#  'vaccinepassport': 561,
#  'savepalestine': 559,
#  'controlavirus': 558,
#  'fascism': 551,
#  'government': 549,
#  'israeliterrorism': 548,
#  'novaccinepassport': 545,
#  'technology': 544,
#  'cle': 542,
#  'draintheswamp': 542,
#  'india': 542,
#  'foxnews': 541,
#  'twitter': 538,
#  'lnyhbt': 533,
#  'ccpvirus': 532,
#  'transhumanism': 531,
#  'ontario': 529,
#  'cdc': 529,
#  'globalist': 529,
#  'cryptocurrency': 528,
#  'business': 527,
#  'us': 527,
#  'crypto': 526,
#  'giftcard': 526,
#  'coronavirusindia': 525,
#  'gates': 525,
#  'pis': 524,
#  'dictaturesanitaire': 523,
#  'soy2030': 523,
#  'nomask': 521,
#  'all': 520,
#  'markofthebeast': 519,
#  'grandreset': 516,
#  'lockdown2021': 515,
#  'ai': 514,
#  'avondklok': 511,
#  'blacklivesmatter': 510,
#  'themoreyouknow': 510,
#  'kuchtosharamkaro': 505,
#  'cnn': 505,
#  'shamelesspoliticians': 502,
#  'fakepandemic': 501,
#  'vaccinated': 501,
#  'decadeofaction': 498,
#  'africa': 497,
#  'vaccin': 494,
#  'this': 494,
#  'ods5': 491,
#  'gop': 491,
#  'thetruth': 490,
#  'alaqsaunderattack': 490,
#  'apocalypse': 488,
#  'nuevanormalidad': 479,
#  'gobiernocriminalycorrupto': 478,
#  'ohio': 477,
#  'kaag': 475,
#  'scam': 473,
#  'trudeaumustgo': 473,
#  'vrijheid': 472,
#  'd66': 471,
#  'europe': 470,
#  'freethinker': 464,
#  'cabal': 463,
#  'sdg': 463,
#  'fueraonu': 457,
#  'science': 456,
#  'sarscov2': 454,
#  'pcrtest': 453,
#  'freedomofspeech': 452,
#  'prensabasura': 451,
#  'qanon': 450,
#  'energy': 448,
#  'history': 448,
#  'matrix': 447,
#  'patriots': 447,
#  'agenda30': 446,
#  'donaldtrump': 445,
#  'liberalismisamentaldisorder': 441,
#  'breakfast': 440,
#  'money': 438,
#  'stemnederlandterug': 436,
#  'mask': 434,
#  'eugenics': 434,
#  'pmcbankcrisis': 432,
#  'education': 432,
#  'electionfraud': 430,
#  'germany': 429,
#  'wwehof': 429,
#  'life': 429,
#  'americans': 429,
#  'podcasts': 428,
#  'protest': 428,
#  'chemtrails': 427,
#  'globalism': 427,
#  'thebeast': 425,
#  'mividamioxígeno': 424,
#  'thebattle': 424,
#  'esdfor2030': 423,
#  '4ir': 422,
#  'mrna': 421,
#  'oms': 421,
#  'cia': 421,
#  'hiphop': 420,
#  'theprince': 420,
#  'kag': 418,
#  'hugodejongekanniks': 417,
#  'polqc': 417,
#  'vacunas': 415,
#  'nhs': 414,
#  'wedonotconsent': 414,
#  'facts': 414,
#  'covidscam': 413,
#  'stemfvd': 413,
#  'elite': 412,
#  'wakeupworld': 411,
#  'facebook': 410,
#  'florida': 409,
#  'coronahoax': 409,
#  'btc': 409,
#  'awake': 408,
#  'viruschino': 407,
#  'iran': 406,
#  'truthmatters': 403,
#  'novaccine': 403,
#  'unitednations': 399,
#  'apagalatele': 398,
#  'vrijheidskaravaan': 397,
#  'pnr': 395,
#  'technocracy': 394,
#  'evil': 394,
#  'populationcontrol': 393,
#  'humanity': 391,
#  'sheep': 390,
#  'work': 390,
#  'globalfascism': 389,
#  'globaldigitalreset': 389,
#  'popefrancis': 386,
#  'sustainabledevelopment': 386,
#  'racism': 385,
#  'greennewdeal': 383,
#  'sleep': 380,
#  'getup': 380,
#  'rt': 380,
#  'fiatburn2018': 379,
#  'desobedienciacivilya': 379,
#  '1team': 378,
#  'convid': 378,
#  'sustainability': 377,
#  'wakeupeverybody': 377,
#  'insidejob': 376,
#  'christian': 373,
#  'masksoff': 373,
#  'texas': 372,
#  'medioambiente': 372,
#  'alert': 371,
#  'vvd': 369,
#  'election2020': 368,
#  'constitution': 368,
#  'wrestlemania': 367,
#  'coronadiktatur': 366,
#  'vaccineinjury': 364,
#  'antifa': 364,
#  'podcasting': 362,
#  '2a': 362,
#  'survival': 361,
#  'fba': 361,
#  'medicalgenocide': 359,
#  'brexit': 357,
#  'climatecrisis': 357,
#  'motivation': 357,
#  'episode': 356,
#  'ufo': 356,
#  'digitaltransformation': 356,
#  'daretothink': 355,
#  'pcrfalsospositivos': 354,
#  'wtf': 352,
#  'lockstep': 352,
#  'podcaster': 352,
#  'covidiot': 351,
#  'narendramodi': 351,
#  'itsstationary': 349,
#  'idonotconsent': 349,
#  'rap': 346,
#  'nowyład': 345,
#  'offgrid': 344,
#  'staywoke': 343,
#  'schwab': 343,
#  'gestapo': 341,
#  'farmafia': 341,
#  'survivalist': 339,
#  'b1': 339,
#  'fantasy': 338,
#  'auspol': 338,
#  'london': 337,
#  'teoriespiskowe': 336,
#  'thriller': 336,
#  'xrp': 335,
#  'photooftheday': 335,
#  'trumpwon': 331,
#  'ideas': 331,
#  'pandemie': 330,
#  'writingcommunity': 329,
#  'actnow': 329,
#  'romance': 327,
#  'negociocriminal': 327,
#  'think': 325,
#  'brainwashed': 325,
#  'deception': 324,
#  'vacuna': 324,
#  'art': 324,
#  'sleepy': 324,
#  'conspiracytheories': 323,
#  'cancelculture': 323,
#  'colombia': 321,
#  'firefauci': 321,
#  'pmcbankvictims': 320,
#  'argentina': 318,
#  'jesuschrist': 318,
#  'covidlies': 317,
#  'bigtechcensorship': 317,
#  'cleveland': 317,
#  'workout': 316,
#  'moderna': 316,
#  'sunrise': 316,
#  'cambioclimático': 316,
#  'kutkaag': 315,
#  'yonosoyzombie': 315,
#  'tyrany': 313,
#  'civildisobedience': 312,
#  'globalismo': 312,
#  'conspiracytheory': 311,
#  'koronawirus': 310,
#  'persconferentie': 309,
#  'blockchain': 307,
#  'decadadeaccion': 307,
#  'stopdelockdown': 307,
#  'wrestling': 305,
#  'agenda2021': 304,
#  'australia': 303,
#  'weareatwar': 302,
#  'voterfraud': 302,
#  'peace': 301,
#  'stopthecoup': 300,
#  'governmentcorruption': 299,
#  'laudy': 299,
#  'gaslighting': 299,
#  'republican': 298,
#  'impfung': 297,
#  'granreseteo': 297,
#  'msmlies': 296,
#  'tech': 295,
#  'trump2024': 295,
#  'nodejaranadieatrás': 294,
#  'thegreatawakeningworldwide': 294,
#  'trudeaucorruption': 294,
#  'investing': 293,
#  'fake': 292,
#  'rse': 292,
#  'falseflag': 291,
#  '2030agenda': 289,
#  'totalitarianism': 289,
#  'vatican': 288,
#  'nyc': 288,
#  'bidencrimefamily': 288,
#  'ods3': 287,
#  'martiallaw': 286,
#  'orwell': 286,
#  'faith': 286,
#  'takeoffyourmask': 285,
#  'borisjohnson': 284,
#  'unity': 283,
#  'fvd': 283,
#  'vaccinations': 282,
#  'ikprikhetniet': 282,
#  'maskup': 282,
#  'vegan': 280,
#  'fear': 280,
#  'imf': 279,
#  'scandemic': 278,
#  'hulkhogan': 277,
#  'beautiful': 277,
#  'tiktok': 277,
#  'france': 276,
#  'politicians': 276,
#  'lamestreammedia': 276,
#  'greendeal': 275,
#  'bidenlied': 275,
#  'ndpol': 274,
#  'vn': 274,
#  'ods4': 273,
#  'hawaii': 273,
#  'antilockdown': 273,
#  'nazism': 273,
#  '4thindustrialrevolution': 272,
#  'manipulation': 272,
#  'endlockdown': 272,
#  'kubrom': 272,
#  'rollover2018': 271,
#  'backtonormal': 271,
#  'zionism': 270,
#  'politiegeweld': 270,
#  'aliens': 269,
#  'ods13': 269,
#  'coronavaccine': 268,
#  'tired': 268,
#  'rothschild': 267,
#  'svpol': 266,
#  'govegan': 265,
#  'oneworldgovernment': 265,
#  'endaipac': 264,
#  'bigreset': 263,
#  'coffeetime': 263,
#  'people': 262,
#  'amitshah': 262,
#  'fbi': 261,
#  'coronavirushoax': 260,
#  'rock': 260,
#  'impeachbiden': 259,
#  'timeisrunningout': 259,
#  'fiction': 259,
#  'finalsolution': 259,
#  'liberals': 258,
#  'npo': 257,
#  'ikdoenietmeermee': 257,
#  'hypocrisy': 256,
#  'mentalhealth': 256,
#  'flu': 255,
#  'cv1984': 255,
#  'nolockdown': 254,
#  'reopenamerica': 254,
#  'shieldshigh': 254,
#  'newyork': 254,
#  'despiertacolombia': 253,
#  'repent': 253,
#  'szczepienia': 253,
#  'personnedecôté': 253,
#  'desobedienciacivilmundial': 252,
#  'nuevaanormalidad': 252,
#  'police': 252,
#  'theemperor': 252,
#  'saveamerica': 251,
#  'bmsproject': 251,
#  'photography': 250,
#  '1a': 250,
#  'orwell1984': 249,
#  'bekind': 248,
#  'demmink': 248,
#  'stopdictaturesanitaire': 248,
#  'szczepimysię': 248,
#  'omsbasura': 248,
#  'versoepelingen': 247,
#  'endlockdowns': 247,
#  'followthemoney': 247,
#  'awakening': 247,
#  'california': 246,
#  'congress': 246,
#  'apartheid': 245,
#  'covid21': 245,
#  'mondooggi': 245,
#  'kindleunlimited': 245,
#  'success': 244,
#  'nuevamortalidad': 244,
#  'traitor': 244,
#  'tikautsav': 244,
#  'socialdistancing': 243,
#  'corrupt': 243,
#  'igualdad': 243,
#  'saveourchildren': 243,
#  'palestineunderattack': 242,
#  'vaccinatiepaspoort': 242,
#  'plandemi': 242,
#  'hollywood': 241,
#  'borisjohnsonout': 241,
#  'wwf': 241,
#  'trumpnews': 241,
#  'bbcnews': 241,
#  'amreading': 241,
#  'communist': 241,
#  'bidenharris': 241,
#  'resistance': 240,
#  'quitatubozal': 240,
#  'happy': 240,
#  'szczepimysie': 240,
#  'nature': 239,
#  'justice': 239,
#  'american': 239,
#  'noaltoquedequeda': 238,
#  'greatawakening': 238,
#  'wuhan': 237,
#  'nouvelordremondial': 237,
#  'openyoureyes': 236,
#  'bozalgenocidioglobal': 236,
#  'mondaythoughts': 236,
#  'vacunascovid19': 236,
#  'rockefeller': 236,
#  'northkorea': 235,
#  'animallovers': 235,
#  'ontariolockdown': 235,
#  'saturday': 234,
#  'ods6': 234,
#  'dictatorship': 234,
#  'stopthesteai2020': 234,
#  'demonstratie': 233,
#  'fraude': 233,
#  'holybible': 232,
#  'revolution': 232,
#  'factsmatter': 231,
#  'naodeixeninguemparatras': 231,
#  'democratstheenemywithin': 231,
#  'mondaymotivation': 231,
#  'nuremberg2021': 231,
#  'liberalismistherealpandemic': 230,
#  'war': 230,
#  'mkultra': 230,
#  'buildbackbetterdebat': 229,
#  'sinbozalmasnatural': 229,
#  'trending': 228,
#  'pushback': 228,
#  'youtuber': 228,
#  'donotcomply': 228,
#  'bigbrother': 228,
#  'climate': 227,
#  'buenosdias': 227,
#  'stopthegreatreset': 226,
#  'skynews': 226,
#  'despertar': 226,
#  'stayhome': 226,
#  'nederlandontwaakt': 226,
#  'ohiostate': 226,
#  'covid19ab': 225,
#  'bidensamerica': 225,
#  'georgiaguidestones': 225,
#  '1984ishere': 224,
#  'pmmodi': 224,
#  'dhs': 223,
#  'yonomeconfino': 223,
#  'godwins': 222,
#  'potus': 221,
#  'power': 221,
#  'milgramexperiment': 220,
#  'amazing': 220,
#  'goodvibes': 220,
#  'savethechildren': 220,
#  'morningmotivation': 220,
#  'agenda2050': 219,
#  'coronadebat': 219,
#  'sun': 219,
#  'sedition': 219,
#  'animalrights': 218,
#  'policebrutality': 218,
#  'dystopia': 218,
#  'abpoli': 218,
#  'children': 218,
#  'ods17': 218,
#  'elpeorgobiernodelahistoria': 217,
#  'blackfirst': 217,
#  'covidvaccination': 216,
#  'odsuas': 216,
#  'morningvibes': 216,
#  'votersuppression': 216,
#  'cagsil': 215,
#  'antichrist': 215,
#  'tyrants': 215,
#  'unmask': 215,
#  'censura': 215,
#  'educación': 215,
#  'infektadura': 214,
#  'stopthesteai': 214,
#  'spain': 214,
#  'lmmusic': 214,
#  'hugomoetsnelweg': 213,
#  'dictatuur': 212,
#  'staysafe': 212,
#  'slavery': 212,
#  'lockdown3': 212,
#  'barcelona': 212,
#  'chinajoe': 211,
#  'cambioclimatico': 211,
#  'theeagle': 210,
#  'vaccinatie': 210,
#  'ods8': 210,
#  'diktatur': 210,
#  'nooitmeerrutte': 210,
#  'putin': 209,
#  'gobiernodeinutiles': 209,
#  'stockholmsyndrom': 209,
#  'museumplein': 209,
#  'trudeau': 209,
#  'mexico': 209,
#  'covid20': 209,
#  'resistthereset': 208,
#  'macron': 208,
#  'putthatinyourpipe': 207,
#  'palestine': 207,
#  'bidencrimefamilly': 206,
#  'policeforfreedom': 206,
#  'polska': 206,
#  'bidermannsdiagramm': 206,
#  'beach': 206,
#  'daily': 206,
#  'obama': 205,
#  'eeuu': 205,
#  'kestäväkehitys': 205,
#  'vaxxed': 204,
#  'dems': 204,
#  'babylon': 204,
#  'washingtondc': 204,
#  'podcasters': 204,
#  'metal': 204,
#  'bbc': 203,
#  'wearamask': 203,
#  'povnow': 201,
#  'humanidad': 201,
#  'cda': 201,
#  'global': 200,
#  'christmas': 200,
#  'alllivesmatter': 199,
#  'elitesgenocidas': 199,
#  'weekend': 199,
#  'prophecy': 199,
#  'linwood': 199,
#  'family': 198,
#  'bookboost': 198,
#  'actúaahora': 198,
#  'poetry': 198,
#  'onebodyinyahawashi': 198,
#  'southflorida': 198,
#  'cuba': 197,
#  'monday': 197,
#  'humanrightsviolations': 197,
#  'bigdata': 197,
#  'free': 197,
#  'future': 196,
#  'ivermectin': 196,
#  'uprising': 195,
#  'svilupposostenibile': 194,
#  'marxism': 194,
#  'mark': 193,
#  'ccpchina': 193,
#  'nosgobiernancriminales': 192,
#  'aew': 192,
#  'redessociales': 192,
#  'wake': 191,
#  'saturdaymorning': 191,
#  'speakup': 191,
#  'vlog': 191,
#  'morningroutine': 191,
#  'food': 190,
#  'justiceforquebecstudents': 190,
#  'geoengineering': 190,
#  'presidenttrump': 189,
#  'tryants': 189,
#  'objetivosdedesarrollosostenible': 189,
#  'sustainabledevelopmentgoals': 189,
#  'flatearth': 189,
#  'foroalc2030': 189,
#  'coronainfoch': 189,
#  'bcpoli': 189,
#  'covidpassport': 188,
#  'catalunya': 188,
#  'mustread': 187,
#  'redpill': 187,
#  'jazz': 187,
#  'nurembergcode': 187,
#  'noahsarmy': 187,
#  'ableg': 187,
#  'dogecoin': 186,
#  'covidiota': 186,
#  'impfzwang': 186,
#  'madrid': 186,
#  'socialmedia': 186,
#  'coronaviruspandemic': 185,
#  'funk': 185,
#  'fightforfreedom': 185,
#  'dkpol': 185,
#  'humantrafficking': 185,
#  'billyjack': 185,
#  'bed': 185,
#  'fakenewsmedia': 185,
#  'mornings': 185,
#  'caffeine': 184,
#  'spiritual': 184,
#  'spotify': 184,
#  'warpspeed': 184,
#  'faucifraud': 183,
#  'notmypresident': 183,
#  'ue': 183,
#  'espana': 183,
#  'vlogger': 183,
#  'christianity': 183,
#  'ods12': 183,
#  'crimesagainstchildren': 183,
#  'stayoncode': 183,
#  'sundayvibes': 183,
#  'share': 183,
#  'dailyvlog': 182,
#  'brainwashing': 182,
#  'genocideingaza': 182,
#  'coronavirusvaccine': 181,
#  'satanic': 181,
#  'racist': 181,
#  'osu': 181,
#  'peru': 181,
#  'theeu': 180,
#  'españaanestesiada': 180,
#  'sostenible': 180,
#  'orwellian': 180,
#  'saneerdenpo': 180,
#  'church': 180,
#  'bellgium': 180,
#  'holdtheline': 179,
#  'enjoylife': 179,
#  'democrat': 179,
#  'fortlauderdale': 179,
#  'salud': 178,
#  'arrestbillgates': 178,
#  'privacy': 178,
#  'mybodymychoice': 177,
#  'reality': 177,
#  'vloggerlife': 177,
#  'elonmusk': 177,
#  'savesheikhjarrah': 177,
#  'shameless': 177,
#  'change': 177,
#  'oh': 176,
#  'retweet': 176,
#  'research': 176,
#  'impfpass': 176,
#  'thenewnormal': 176,
#  'wwg1wga': 176,
#  'genocidiomundial': 175,
#  'italia': 175,
#  'stemteamthierry': 175,
#  'coronavirusuk': 175,
#  'endofdays': 175,
#  'entrepreneur': 175,
#  'canpoli': 175,
#  'guncontrol': 174,
#  'planetlockdown': 174,
#  'moscow': 174,
#  'pizzagate': 174,
#  'stemteamwybren': 174,
#  'day': 174,
#  'google': 174,
#  'jfk': 173,
#  'gopcomplicittraitors': 173,
#  'cdmx': 173,
#  'covidcult': 173,
#  'stemderestweg': 173,
#  'ireland': 173,
#  'radio': 173,
#  'wakeupcanada': 173,
#  'derechoshumanos': 173,
#  'dailymotivation': 173,
#  'merkelmussweg': 172,
#  'live': 172,
#  'payattention': 172,
#  'bidenbordercrisis': 172,
#  'otwieramy': 172,
#  'pandemiamundial': 172,
#  'dc': 171,
#  'hypocrites': 171,
#  'operationmockingbird': 170,
#  'sunshine': 170,
#  'immunity': 170,
#  'londonprotest': 170,
#  'psychedelic': 170,
#  'coronacircus': 170,
#  'agua': 170,
#  'medicosporlaverdad': 169,
#  'europa': 169,
#  'zionazi': 169,
#  'blacktwitter': 168,
#  'democratsarecorrupt': 168,
#  'ods11': 168,
#  'knowledge': 168,
#  'ecologia': 167,
#  'scotthall': 167,
#  'filmyourhospital': 167,
#  'psyops': 167,
#  'georgesoros': 167,
#  'memes': 167,
#  'odsccoo': 167,
#  'alberta': 167,
#  'bidencheated2020': 167,
#  'spy': 167,
#  'video': 166,
#  'nomascuarentena': 166,
#  'rtl': 166,
#  'quedateencasa': 166,
#  'wormwood': 166,
#  'paris': 166,
#  'ajenjo': 166,
#  'apple': 165,
#  'morningcoffee': 165,
#  'mainstreammedia': 165,
#  'nowplaying': 165,
#  'stoplockdown': 165,
#  'noantiblackracism': 165,
#  'fridaymorning': 165,
#  'tecnología': 165,
#  'masteroftides': 165,
#  'kingchaos': 165,
#  'agendaurbana': 165,
#  'pray': 165,
#  'gopseditioustraitors': 164,
#  'ods16': 164,
#  'anglesey': 164,
#  'medicaltyranny': 164,
#  'economie': 164,
#  'stimulus': 163,
#  'iartg': 163,
#  'stopconfinement': 163,
#  'commonsense': 163,
#  'endsars': 163,
#  'podcastlife': 163,
#  'wakingup': 163,
#  'desinformación': 163,
#  'opendemminkvvdbeerput': 162,
#  'broward': 162,
#  'capitolriots': 162,
#  'pop': 162,
#  'epstein': 162,
#  'texascovid': 162,
#  'nwo4life': 162,
#  'spring': 161,
#  'texascovid19': 161,
#  'writing': 161,
#  'security': 161,
#  'theworldisastage': 161,
#  'lauderdale': 161,
#  'sleepyjoe': 161,
#  'コロナは茶番': 161,
#  'spirituality': 160,
#  'q': 160,
#  'scummedia': 160,
#  'trap': 160,
#  'sostenibilità': 160,
#  'republic': 160,
#  'parler': 159,
#  'wweraw': 159,
#  'noalamascarillaalairelibre': 159,
#  'climateemergency': 159,
#  ...}

# %% [markdown]
# ### Find tweets associated with fauci

# %%
find_tweets_by_limit(100, ['fauci, #firefauci'])

# %%
thegreatawakening_10k = find_tweets_by_limit(10000, ['#thegreatawakening'])

# %%
find_associated_hashtags(thegreatawakening_10k['hashtags'])
# Out:
# {'thegreatawakening': 10011,
#  'wwg1wga': 1679,
#  'maga': 1010,
#  'thegreatreset': 819,
#  'godwins': 677,
#  'qanon': 626,
#  'deepstate': 559,
#  'kag': 533,
#  'wakeupamerica': 488,
#  'trump2020': 487,
#  'tyranny': 463,
#  'covid19': 415,
#  'fightback': 411,
#  'trump': 341,
#  'stopthecoup': 340,
#  'america': 335,
#  'wearethenewsnow': 332,
#  'darktolight': 320,
#  'savethechildren': 305,
#  'q': 302,
#  'fakenews': 291,
#  'thestorm': 288,
#  'china': 275,
#  'saveamerica': 272,
#  'freedom': 271,
#  'obamagate': 268,
#  'tryants': 253,
#  'greatawakening': 252,
#  'vaccines': 248,
#  'ccpvirus': 246,
#  'uprising': 246,
#  'lockdown': 243,
#  'pushback': 237,
#  'virus': 236,
#  'draintheswamp': 235,
#  'sheepnomore': 235,
#  'wakeup': 227,
#  'civildisobedience': 222,
#  'treason': 222,
#  'truth': 208,
#  'kolr10news': 206,
#  'ky3': 205,
#  'kolr10': 200,
#  'stopthesteal': 194,
#  'ozarks': 193,
#  'ky3news': 193,
#  'ozarkmo': 191,
#  'ksprnews': 190,
#  'shadowgate': 189,
#  'kspr': 189,
#  'ozarksfox': 186,
#  'thegreatawakeningworldwide': 182,
#  'wethepeople': 179,
#  'kolr': 176,
#  'springfieldmo': 156,
#  'americafirst': 147,
#  'wwg1wgaworldwide': 147,
#  'corruption': 142,
#  'kspr33': 138,
#  'trumptrain': 138,
#  'bidencrimefamily': 134,
#  'ky3tv': 131,
#  'ksprtv': 130,
#  'saveourchildren': 128,
#  'maga2020': 127,
#  'factsmatter': 126,
#  'digitalsoldiers': 123,
#  'tyrants': 123,
#  'bransonmo': 123,
#  'trusttheplan': 119,
#  'censorship': 118,
#  'pray': 117,
#  'antifaterrorists': 116,
#  'republican': 114,
#  'awaken': 110,
#  'walkaway': 109,
#  'constitution': 108,
#  'nothingcanstopwhatiscoming': 107,
#  'usa': 107,
#  'tryhardermsm': 106,
#  'freespeech': 102,
#  'propaganda': 100,
#  'conscious': 99,
#  'donaldtrump': 97,
#  'electionfraud': 96,
#  'trumpwon': 96,
#  'enlightenment': 92,
#  '1stamendment': 91,
#  'cia': 88,
#  'nwo': 86,
#  'voterfraud': 86,
#  'patriots': 85,
#  'godblessamerica': 84,
#  'blmmarxists': 84,
#  'plandemic': 80,
#  'love': 79,
#  'enjoytheshow': 77,
#  'qarmy': 77,
#  'operationmockingbird': 77,
#  'awareness': 76,
#  'potus': 75,
#  'finishstrong417': 74,
#  'ascension': 74,
#  'segregationjoe': 70,
#  'pizzagate': 69,
#  'presidenttrump': 68,
#  'conservative': 68,
#  'kag2020': 68,
#  'msm': 68,
#  'holdtheline': 67,
#  'dominion': 67,
#  'liberty': 66,
#  'newworldorder': 66,
#  'ozarksfoxam': 65,
#  'elgrandespertar': 64,
#  'resist': 64,
#  'keepamericagreat': 62,
#  'covid': 62,
#  'coronavirus': 62,
#  'redpill': 61,
#  'election2020': 61,
#  'biden': 61,
#  'rogersvillemo': 59,
#  'digitalsoldier': 59,
#  'news': 57,
#  'gop': 56,
#  'patriotas': 55,
#  'awakening': 55,
#  'thestormhasarrived': 55,
#  'redwave': 54,
#  'bidengate': 54,
#  'themoreyouknow': 53,
#  'trump2020landslide': 53,
#  'wewillnotbesilenced': 53,
#  'vivaespaña': 53,
#  'lomejorestaporvenir': 53,
#  'noseremossilenciados': 53,
#  'thesepeoplearesick': 52,
#  'blm': 52,
#  'querdenker': 52,
#  'bidencrimefamiily': 52,
#  'dondeva1vamostodos': 50,
#  'cnn': 50,
#  'qanons': 50,
#  'scotus': 50,
#  'pedogate': 50,
#  'mailinballots': 49,
#  'god': 48,
#  'querdenken711': 48,
#  'donttreadonme': 48,
#  'wga': 48,
#  'trump2020landslidevictory': 47,
#  'crimesagainsthumanity': 46,
#  'justiceiscoming': 46,
#  'trump2020nowmorethanever': 46,
#  'painiscoming': 46,
#  'supremecourt': 46,
#  'orangecountry': 46,
#  'thebestisyettocome': 46,
#  'wwg': 44,
#  'greatreset': 43,
#  'thestormisuponus': 43,
#  'molonlabe': 43,
#  'españalibre': 42,
#  'spiritualgrowth': 42,
#  'agenda21': 42,
#  'spiritualawakening': 41,
#  'patriotsunited': 41,
#  'makeamericagreatagain': 41,
#  'spirituality': 40,
#  'inittogether': 39,
#  'faith': 39,
#  'kenfm': 39,
#  '2a': 39,
#  'jesus': 39,
#  'ncswic': 39,
#  'patriotsunite': 38,
#  'nothingcanstopwhatscoming': 38,
#  'fromdarktolight': 38,
#  'liberalismisamentaldisorder': 37,
#  'jesuslives': 37,
#  'ageofaquarius': 37,
#  'godsarmy': 37,
#  'consciousness': 37,
#  'bible': 37,
#  '2ndamendment': 36,
#  'patriotsfight': 36,
#  'spiritual': 36,
#  'republicans': 36,
#  'vote': 36,
#  'potus45': 36,
#  'evil': 35,
#  'adrenochrome': 35,
#  'billofrights': 35,
#  'lies': 35,
#  'livefreeordie': 35,
#  'voteredtosaveamerica': 34,
#  'defendamerica': 34,
#  'panicindc': 34,
#  'defundnpr': 34,
#  'guns': 33,
#  'sicsempertyrannis': 33,
#  'restoreamerica': 33,
#  'breaking': 33,
#  'allrightsmatter': 33,
#  'democratsaredestroyingamerica': 33,
#  'fbrparty': 32,
#  'libertarian': 32,
#  'peace': 32,
#  'fourmoreyears': 32,
#  '2ashallnotbeinfringed': 32,
#  'americaortrump': 32,
#  'stopthesteai': 32,
#  'taketheoath': 31,
#  'fpc': 31,
#  'humanity': 31,
#  'soundoffreedom': 31,
#  'hiddenknowledge': 31,
#  'silentmajority': 31,
#  'humantrafficking': 31,
#  'filltheseat': 31,
#  'illuminati': 31,
#  'benghazi': 31,
#  'democrats': 30,
#  'electionday': 30,
#  'patriotsawakened': 30,
#  'meme': 30,
#  'politics': 30,
#  'meditation': 29,
#  'phase3justice': 29,
#  'wwg1gwa': 29,
#  'hcq': 29,
#  'votoauditavelnobrasil': 29,
#  'a': 29,
#  'woke': 29,
#  'thejimmydoreshow': 29,
#  'generalflynn': 29,
#  'votoauditavelja': 28,
#  'countrybeforeparty': 28,
#  'aaronmaté': 27,
#  'juanosavin': 27,
#  'buildbackbetter': 27,
#  'nonewnormal': 27,
#  'maxblumenthal': 27,
#  'alllivesmatter': 27,
#  'childtrafficking': 27,
#  'unitedwestand': 27,
#  'podcast': 26,
#  'blacklivesmatter': 26,
#  '5d': 26,
#  'teamtrump': 26,
#  'live': 25,
#  'antifa': 25,
#  'realdonaldtrump': 25,
#  'americanrescueplan': 25,
#  'cabal': 25,
#  'starseed': 24,
#  'joebiden': 24,
#  'liberalismistherealpandemic': 24,
#  'laptopfromhell': 24,
#  'theworldiswatching': 24,
#  'gitmo': 24,
#  'lightworriers': 24,
#  'questioneverything': 24,
#  'freeassange': 24,
#  'voteredorbedead': 24,
#  'nomasks': 24,
#  'manifestation': 24,
#  'agenda2030': 24,
#  'justice': 24,
#  'consciousvitality': 24,
#  'spaceforcecowboy': 23,
#  'evolution': 23,
#  'positiveinfluencer': 23,
#  'trumpsupporters': 23,
#  'thestormishere': 23,
#  'satanicelite': 23,
#  'vaccine': 23,
#  'pedowood': 23,
#  'repost': 23,
#  'voteredtosaveamerica2020': 23,
#  'bidenharris2020': 22,
#  'voluntaryism': 22,
#  'thegreatresist': 22,
#  'parler': 22,
#  'freedomofspeech': 22,
#  'enlightened': 22,
#  'pain': 22,
#  'winning': 22,
#  'jfkjr': 22,
#  'trump2024': 22,
#  'buildthewall': 21,
#  'newnormal': 21,
#  'truthmatters': 21,
#  'lockdowns': 21,
#  'qanonposts': 21,
#  'childabuse': 21,
#  'flagsout': 21,
#  'communist': 21,
#  'satanists': 21,
#  'biblical': 21,
#  'boom': 21,
#  'qmap': 20,
#  'christian': 20,
#  'godspeed': 20,
#  'billgates': 20,
#  'cryptoart': 20,
#  'election': 20,
#  'dimensionalbeings': 20,
#  'nesara': 20,
#  'larp': 20,
#  'risingyourvibratons': 20,
#  'podcasts': 20,
#  'unity': 20,
#  'podcasting': 20,
#  'godblesspresidenttrump': 19,
#  'fightlikeaflynn': 19,
#  'jeffreyepstein': 19,
#  'covidhoax': 19,
#  'breakingnews': 19,
#  'endhumantrafficking': 19,
#  'abrahamaccords': 19,
#  'corona': 19,
#  'itshappening': 19,
#  'obama': 19,
#  'trump2020tosaveamerica': 19,
#  'covid19hoax': 19,
#  'comufascistdemocrats': 19,
#  'unitednotdivided': 19,
#  '4moreyears': 19,
#  'greatawakeningworldwide': 18,
#  'westandtogether': 18,
#  'ohio': 18,
#  'starseeds': 18,
#  'trumpmemes': 18,
#  'nsa': 18,
#  'agenda30': 18,
#  'ccp': 18,
#  'scamdemic': 18,
#  'godwinsalways': 18,
#  'communism': 18,
#  'pedophilia': 18,
#  'dankmemes': 18,
#  'electionintegrity': 18,
#  'fightfortrump': 18,
#  'funny': 17,
#  'gesara': 17,
#  'sedition': 17,
#  'godwon': 17,
#  'nofear': 17,
#  'rubikon': 17,
#  'lightworker': 17,
#  'awake': 17,
#  'patriot': 17,
#  'spygate': 17,
#  'herecomesthepain': 17,
#  'bidencheated': 17,
#  'wearethestorm': 17,
#  'this': 17,
#  'falseflag': 17,
#  'blexit': 17,
#  'rednationrising': 17,
#  'podcastlife': 16,
#  'foxnews': 16,
#  'theshift': 16,
#  'mandatorymasks': 16,
#  'memewar': 16,
#  'bluelivesmatter': 16,
#  'chinajoebiden': 16,
#  'holybible': 16,
#  'evolvingsouls': 16,
#  'selflove': 16,
#  'abundance': 16,
#  'scienceortrump': 16,
#  'thegreatconjunction': 16,
#  'episode': 16,
#  'cle': 16,
#  'socialism': 16,
#  'agenda': 16,
#  'daretothink': 16,
#  'thestormiscoming': 16,
#  'podcasters': 16,
#  'podcaster': 16,
#  'c0vid19': 15,
#  'humanrights': 15,
#  'bhfyp': 15,
#  'epstein': 15,
#  'altpunks': 15,
#  'globalist': 15,
#  'astrology': 15,
#  'fakenewsmedia': 15,
#  'australia': 15,
#  'releasethekraken': 15,
#  'wakethefakeup': 15,
#  'covid1984': 15,
#  'jesuschrist': 15,
#  'merkelgate': 15,
#  'votered': 15,
#  'conspiracy': 15,
#  'dementiadonald': 15,
#  'scylt': 15,
#  'kraken': 15,
#  'godschildren': 15,
#  'billgatesisevil': 15,
#  'trump2021': 15,
#  'lucidblack': 15,
#  'hunterbidenlaptop': 14,
#  'oarksfox': 14,
#  'spiritualwarfare': 14,
#  'jfk': 14,
#  'deepstateexposed': 14,
#  'nftcommunity': 14,
#  'light': 14,
#  'firstamendment': 14,
#  'childsexring': 14,
#  'nobelpeaceprize': 14,
#  'wisdom': 14,
#  'fightforfreedom': 14,
#  'soundcloud': 14,
#  'fightback2021': 14,
#  'fallofthecabal': 14,
#  'cue': 14,
#  'liberal': 14,
#  'keepamericasafe': 14,
#  'billysix': 14,
#  'crimesagainstchildren': 13,
#  'donaldjtrump': 13,
#  'canada': 13,
#  'roadto10ksubstilljune': 13,
#  'higherconsciousness': 13,
#  'standwithtrump': 13,
#  'goodmorning': 13,
#  'wwg1wga_worldwide': 13,
#  'riseup': 13,
#  'trumphidthetruth': 13,
#  '目覚めろ日本人': 13,
#  'qanoncult': 13,
#  'blackexcellence': 13,
#  'enoughisenough': 13,
#  'followthemoney': 13,
#  '素晴らしい大覚醒': 13,
#  'christconsciousness': 13,
#  'bethechange': 13,
#  'maxotte': 13,
#  'fraud': 13,
#  'truthseekers': 13,
#  'killaryclinton': 13,
#  'hunterbiden': 13,
#  'president': 13,
#  'hillaryclintonforprison': 13,
#  'life': 13,
#  'smartmatic': 13,
#  'traitor': 13,
#  'bungals': 12,
#  'maxspiers': 12,
#  'covidiots': 12,
#  'elections2020': 12,
#  'stophumantrafficking': 12,
#  'uk': 12,
#  'weareone': 12,
#  'foreverwoke': 12,
#  'donaldtrump2020': 12,
#  'cleveland': 12,
#  'ai': 12,
#  'mkultra': 12,
#  'jpunksgetty': 12,
#  'photooftheday': 12,
#  'lovewins': 12,
#  'unityconsciousness': 12,
#  'epsteinisland': 12,
#  'trumpdoesntcare': 12,
#  'chemtrails': 12,
#  'disclosure': 12,
#  'ashlibabbitt': 12,
#  'nuremberg2': 12,
#  'deepstatecabal': 12,
#  'researchanddestroy': 12,
#  'sidneypowell': 12,
#  'patriotes': 12,
#  'unofficialpunks': 12,
#  'truthseeker': 12,
#  'theevent': 12,
#  '2020election': 12,
#  'twitter': 11,
#  'clm': 11,
#  'americastrong': 11,
#  'revelations': 11,
#  'takedowndeepstate': 11,
#  'bitcoin': 11,
#  'londonprotest': 11,
#  'sheeple': 11,
#  'hunterbidenemails': 11,
#  'openyoureyes': 11,
#  'qdrops': 11,
#  'biglie': 11,
#  'stopthestealmarch': 11,
#  'ukraine': 11,
#  'bigpharma': 11,
#  'vatican': 11,
#  'beautifuldreamer': 11,
#  'factsnotfear': 11,
#  'stopthecensorship': 11,
#  'whitehouse': 11,
#  'legrandreveil': 11,
#  'saveamericamarch': 11,
#  'healing': 11,
#  'soul': 11,
#  'evergiven': 11,
#  'wwg1wwga': 11,
#  'itsnotover': 11,
#  'qnon': 11,
#  'christwithin': 11,
#  'pobudka': 11,
#  'esoteric': 11,
#  'soundoffreedomfullmovie': 11,
#  'revival': 11,
#  'soros': 11,
#  'humantraffickingawareness': 11,
#  'whereishunter': 11,
#  'exposingthetruth': 11,
#  'qanon2020': 11,
#  'oann': 11,
#  'soundoffreedommovie': 11,
#  'stopthegreatreset': 11,
#  'wedonotconsent': 11,
#  'motivation': 11,
#  'endtimes': 10,
#  'eo13848': 10,
#  '陰謀論': 10,
#  'loosewomen': 10,
#  'governmentcorruption': 10,
#  '日本人とは何者なのか': 10,
#  'applepodcasts': 10,
#  'goodvsevil': 10,
#  'patriotshavenoskincolor': 10,
#  'twittercensorship': 10,
#  'nomorelockdowns': 10,
#  'patriotprayer': 10,
#  'john316': 10,
#  'obamaknew': 10,
#  'koronawirus': 10,
#  'spotify': 10,
#  'knowledgeispower': 10,
#  'qpost': 10,
#  'wwg1wwa': 10,
#  'selfrealisation': 10,
#  'epsteindidntkillhimself': 10,
#  'whoami': 10,
#  'health': 10,
#  'endthecabal': 10,
#  'qnews': 10,
#  'アメノウズメ塾': 10,
#  'ディープステート': 10,
#  'martiallawnow': 10,
#  'drainthedemons': 10,
#  'freemason': 10,
#  'globalreset': 10,
#  'stopthesteai2020': 10,
#  'secretknowledge': 10,
#  'elections': 10,
#  'redoctober': 10,
#  'democratsarecorrupt': 10,
#  'rigged': 10,
#  'hollywood': 10,
#  'np': 9,
#  'anons': 9,
#  'takebacktheworld': 9,
#  'unmask': 9,
#  'patriotparty': 9,
#  'newearth': 9,
#  'drainthedeepstateswamp': 9,
#  'globalists': 9,
#  'fightforamerica': 9,
#  'keepfightingmrpresident': 9,
#  'simulationtheory': 9,
#  'apple': 9,
#  'clintonbodycount': 9,
#  'wuju': 9,
#  'prolife': 9,
#  'energy': 9,
#  'bebest': 9,
#  'worldwide': 9,
#  'media': 9,
#  'lockthemallup': 9,
#  'ikprikhetniet': 9,
#  'enemyofthepeople': 9,
#  'marchfortrump': 9,
#  'event201': 9,
#  'lockthemup': 9,
#  'fucktrump': 9,
#  'aliens': 9,
#  'qanonworldwide': 9,
#  'breakthelockdowns': 9,
#  'family': 9,
#  'vaccination': 9,
#  '144k': 9,
#  'fbicorruption': 9,
#  'revolution': 9,
#  'wtp': 9,
#  'hope': 9,
#  'bordercrisis': 9,
#  'justsayno': 9,
#  'bidencheated2020': 9,
#  'walkawayfromdemocrats': 9,
#  'bidenharris': 9,
#  'united': 9,
#  'fullaudit': 9,
#  'frequency': 9,
#  'jesusismyking': 9,
#  'proudboys': 9,
#  'trending': 8,
#  'davidicke': 8,
#  'youtube': 8,
#  'raisethevibe': 8,
#  'informationwar': 8,
#  'thegreatrevival': 8,
#  'wef': 8,
#  'qproof': 8,
#  'liberals': 8,
#  'covidscam': 8,
#  'kbf': 8,
#  'nancypelosi': 8,
#  'the5thdimension': 8,
#  'wwg1wgaww': 8,
#  'stopglobalism': 8,
#  'idonotconsent': 8,
#  'economy': 8,
#  'wewinthepeople': 8,
#  'ecocommunities': 8,
#  'democrat': 8,
#  'symbolismwillbetheirdownfall': 8,
#  'pizzagateisreal': 8,
#  'thismorning': 8,
#  'therestorationplan': 8,
#  'theapocalypse': 8,
#  'trumpwon2020': 8,
#  'thinkingoutofthebox': 8,
#  'godblessourmilitary': 8,
#  'truthbetold': 8,
#  'onenationundergod': 8,
#  'video': 8,
#  'thegreatremembrance': 8,
#  'witchunt': 8,
#  'quarantine': 8,
#  'advaitavedanta': 8,
#  'haiti': 8,
#  'godblessourtroops': 8,
#  'protectourchildren': 8,
#  'stormisuponus': 8,
#  'takebackourcountry': 8,
#  'qfs': 8,
#  'thegreatcleaning': 8,
#  'flatearth': 8,
#  'followthewhiterabbit': 8,
#  'becomeungovernable': 8,
#  'jimcaviezel': 8,
#  'darak': 8,
#  'clintonfoundation': 8,
#  'fisa': 8,
#  'scamdemic2020': 8,
#  'promiseskept': 8,
#  'bestpresidentever': 8,
#  'theblueprintfilm': 8,
#  'spiritualcommunities': 8,
#  'ickonicmediaoriginal': 8,
#  'wwgowga': 8,
#  'consciousnessexpansion': 8,
#  'xrp': 8,
#  'crumbs': 8,
#  'lawandorder': 8,
#  'terrorist': 8,
#  'lovewillprevail': 8,
#  'savehumanity': 8,
#  'riggedelection': 7,
#  'polska': 7,
#  'texas': 7,
#  'justicematters': 7,
#  'letfreedomring': 7,
#  'davosagenda': 7,
#  'abortionismurder': 7,
#  'electiontheft': 7,
#  'powertothepeople': 7,
#  'ifbap': 7,
#  'history': 7,
#  'spotifypodcast': 7,
#  'schumannresonance': 7,
#  'quantumfinancialsystem': 7,
#  'reset': 7,
#  'amyconeybarrett': 7,
#  'morning': 7,
#  'apocalypse': 7,
#  'beautifulrevolution': 7,
#  'thenewnormal': 7,
#  'mirasorvino': 7,
#  'thehuntforredoctober': 7,
#  'covid_19': 7,
#  'jesuschristislord': 7,
#  'orpuw': 7,
#  'prajnaparamita': 7,
#  'organharvesting': 7,
#  'possibilities': 7,
#  'maga2020landslidevictory': 7,
#  'montreal': 7,
#  'yoga': 7,
#  'joy': 7,
#  'jesusislord': 7,
#  '洗脳': 7,
#  'chinajoe': 7,
#  'forgodandcountry': 7,
#  'cancelculture': 7,
#  'jesusisthesonofgod': 7,
#  'one': 7,
#  'trumpbankruptingamerica': 7,
#  'amen': 7,
#  'barackobama': 7,
#  'london': 7,
#  'msnbc': 7,
#  'waarligtjougrens': 7,
#  'blmmovement': 7,
#  'hillaryclinton': 7,
#  'raiseyourvibration': 7,
#  'qdrop': 7,
#  'mustwatch': 7,
#  'billcamp': 7,
#  'votetrump2020': 7,
#  'justiceforallamericans': 7,
#  'warroom2020': 7,
#  'melanin': 7,
#  'berniesanders': 7,
#  'populationcontrol': 7,
#  'thepurge': 7,
#  'declass': 7,
#  'covidvaccine': 7,
#  'rothschild': 7,
#  'christianity': 7,
#  'thinkforyourself': 7,
#  'allinthistogether': 7,
#  'clintoncrimefamily': 7,
#  'music': 7,
#  'kek': 7,
#  'prayer': 7,
#  'art': 7,
#  'notmypresident': 7,
#  'stemzeweg': 7,
#  'beyondtheparroted': 7,
#  'xaviernaidoo': 7,
#  'takethechance': 7,
#  'power': 7,
#  'protest': 7,
#  'klausschwab': 7,
#  'itshabbening': 7,
#  'mockingbirdmedia': 7,
#  'martiallaw': 7,
#  'empowering': 7,
#  'lightworkers': 7,
#  'joebidenisnotmypresident': 7,
#  'daretofly': 7,
#  'dismantlethesystem': 6,
#  'conspiracytheories': 6,
#  'facts': 6,
#  'enditmovement': 6,
#  'mega': 6,
#  'taketheleap': 6,
#  'declassifyeverything': 6,
#  'midnightriders': 6,
#  'futureprovespast': 6,
#  'occult': 6,
#  'spirit': 6,
#  'trump2q2q': 6,
#  'nftcollectors': 6,
#  'savechildren': 6,
#  'anonymous': 6,
#  'bigtech': 6,
#  'seanconnery': 6,
#  'nftcollector': 6,
#  'fulldisclosure': 6,
#  'victory': 6,
#  'endtyranny': 6,
#  'american': 6,
#  'trumplandslide2020': 6,
#  'pedogate2020': 6,
#  'hillaryemails': 6,
#  'interview': 6,
#  'research': 6,
#  'newworld': 6,
#  'elitegenderinversion': 6,
#  'museumofaltart': 6,
#  'obamabinspying': 6,
#  'trafficking': 6,
#  'bestpresidentever45': 6,
#  'grift': 6,
#  'climatechange': 6,
#  'liars': 6,
#  'auditthevote': 6,
#  'wewillvote': 6,
#  'standup': 6,
#  'redwave2020': 6,
#  'futureproofspast': 6,
#  'government': 6,
#  'espionage': 6,
#  'mfga2021': 6,
#  'joebideniscorrupt': 6,
#  'inittoendit': 6,
#  'whereshunter': 6,
#  'ripjamesbond': 6,
#  'guatanamo': 6,
#  'mars': 6,
#  'magaa': 6,
#  'prophecy': 6,
#  'nationalsecurity': 6,
#  'instagood': 6,
#  'godisgood': 6,
#  'childsextrafficking': 6,
#  'decepticons': 6,
#  'youtuber': 6,
#  'klaarmetrutte': 6,
#  'prayforpotus': 6,
#  'ripseanconnery': 6,
#  'anon': 6,
#  'deepstatetakedown': 6,
#  'disruptthedemand': 6,
#  'matrix': 6,
#  'davos': 6,
#  'freemasonry': 6,
#  'gorillaboybeatss': 6,
#  'fullmoon': 6,
#  'unitedwearestrong': 6,
#  'biden2020': 6,
#  'georgia': 6,
#  'covfefe': 6,
#  'nomask': 6,
#  'ww1wga': 6,
#  'mainstreammedia': 6,
#  'nexit': 6,
#  'bidensamerica': 6,
#  'cnntapes': 6,
#  'popart': 6,
#  'fuckthesystem': 6,
#  'ingodwetrust': 6,
#  'moaa': 6,
#  'beingsoflight': 6,
#  'thestormhasbegun': 6,
#  'vibration': 6,
#  'nxivm': 6,
#  'tiktok': 6,
#  'pandemic': 6,
#  'wwgiwga': 6,
#  'covidー19': 6,
#  'ograndedespertar': 6,
#  'nuremberg': 6,
#  'conspiracytheory': 6,
#  'tesla': 6,
#  'theflash': 6,
#  'saveearth': 6,
#  'exposecorruption': 6,
#  'slavesnomore': 6,
#  'dna': 6,
#  'dictatordan': 6,
#  '一切都已經開始': 6,
#  'takeachance': 6,
#  'prayfortrump': 6,
#  'plandemia': 5,
#  'fvd': 5,
#  'spiritualwar': 5,
#  'hunterbidensukrainescandal': 5,
#  'trumpdebtbomb': 5,
#  'staywoke': 5,
#  'natokriegidioten': 5,
#  'gameover': 5,
#  'benghaziaintgoingaway': 5,
#  'goldenretriever': 5,
#  'watchthewater': 5,
#  'ce5meditation': 5,
#  'kingsandqueens': 5,
#  'millionmagamarch': 5,
#  'coronamaatregelen': 5,
#  'qanonsense': 5,
#  'dominiongate': 5,
#  'a1': 5,
#  'deantelano': 5,
#  'trumpcard': 5,
#  'transformation': 5,
#  'georgiaguidestones': 5,
#  'georgesoros': 5,
#  'science': 5,
#  'asabovesobelow': 5,
#  'mybodymychoice': 5,
#  'myblackisbeautiful': 5,
#  'gratitude': 5,
#  'trumpismypresident': 5,
#  'nevada': 5,
#  'trumpmeltdown': 5,
#  'votelikeyourlifedependsonit': 5,
#  'octobersurprise': 5,
#  'countryoverparty': 5,
#  'crookedjoebiden': 5,
#  'enlightment': 5,
#  'thebiglie': 5,
#  'putin': 5,
#  'solarflash': 5,
#  'demonrats': 5,
#  'freedomrally': 5,
#  'soundhealing': 5,
#  'doyourownresearch': 5,
#  'votefornobody': 5,
#  'jesussaves': 5,
#  'thegreatconjuction': 5,
#  'merylstreep': 5,
#  'sydneypowell': 5,
#  'nftpopart': 5,
#  'luciferian': 5,
#  'manipulation': 5,
#  'azaudit': 5,
#  'theartofpunks': 5,
#  'divinefeminine': 5,
#  'republicanparty': 5,
#  'nesaragesara': 5,
#  'grandespertar': 5,
#  'allysarmy': 5,
#  'trumplandside': 5,
#  'goodversusevil': 5,
#  'mexico': 5,
#  'endscamdemic': 5,
#  'drainthedeepstate': 5,
#  'wrwy': 5,
#  'spiritualjourney': 5,
#  'oneloverising': 5,
#  'qsentme': 5,
#  'uselections': 5,
#  'pinealgland': 5,
#  'endtrafficking': 5,
#  'theta': 5,
#  'sundaythoughts': 5,
#  'conservatives': 5,
#  'election2020results': 5,
#  'trumpdoesnotcare': 5,
#  'freeenergy': 5,
#  'joebidencrimefamily': 5,
#  'depopulation': 5,
#  'lawofattraction': 5,
#  'elite': 5,
#  'allpedosshoulddie': 5,
#  'qanon2021': 5,
#  'collectiveconsciousness': 5,
#  'army': 5,
#  'comedy': 5,
#  'democratshateamerica': 5,
#  'portraitphotography': 5,
#  'paincoming': 5,
#  'sun': 5,
#  'domesticterrorists': 5,
#  'nasa': 5,
#  'hillaryclinto': 5,
#  'nomoremasks': 5,
#  'galacticfederation': 5,
#  'pope': 5,
#  'rudygiuliani': 5,
#  'godisincontrol': 5,
#  'lifeforce': 5,
#  'deplorables': 5,
#  'bigtechcensorship': 5,
#  'inspirationalquotes': 5,
#  'electionresults2020': 5,
#  'presidenttrumpwon': 5,
#  'linwood': 5,
#  'rebirth': 5,
#  'panic': 5,
#  'fuckhollywood': 5,
#  'patriotsholdtheline': 5,
#  'defundthemedia': 5,
#  'weinerslaptop': 5,
#  'nooneisabovethelaw': 5,
#  'loveandlight': 5,
#  'jesuit': 5,
#  'ghislainemaxwell': 5,
#  'fillthatseat': 5,
#  'hyperian': 5,
#  'red': 5,
#  'legend': 5,
#  '2q2q': 5,
#  'masksdontwork': 5,
#  'endchildtrafficking': 5,
#  'crypto': 5,
#  'darknesstolight': 5,
#  'grow': 5,
#  'thefutureisblack': 5,
#  'nationalism': 5,
#  'sheep': 5,
#  'tech': 5,
#  'lightwins': 5,
#  'depopulationagenda': 5,
#  'marxists': 5,
#  'armorofgod': 5,
#  'unite': 5,
#  'traitors': 5,
#  'silentnomore': 5,
#  'sayno': 5,
#  'queenelizabet': 5,
#  'smile': 5,
#  'novaccinepassportsanywhere': 5,
#  ...}

# %%
find_associated_hashtags(fauci_100k['hashtags'])
# Out:
# {'firefauci': 90992,
#  'covid19': 3590,
#  'coronavirus': 2623,
#  'firebirx': 2143,
#  'openamericanow': 1772,
#  'fauci': 1712,
#  'obamagate': 1196,
#  'plandemic': 1140,
#  'faucifraud': 1085,
#  'billgates': 1083,
#  'firefaucinow': 1078,
#  'faucithefraud': 906,
#  'trump2020': 850,
#  'maga': 817,
#  'trump': 800,
#  'firetrump': 759,
#  'covid': 725,
#  'fakenews': 706,
#  'covid_19': 678,
#  'cdc': 627,
#  'who': 608,
#  'arrestbillgates': 607,
#  'fireredfield': 584,
#  'wwg1wga': 557,
#  'coronahoax': 552,
#  'vaccines': 540,
#  'hydroxychloroquine': 538,
#  'reopenamerica': 531,
#  'draintheswamp': 519,
#  'fakepandemic': 495,
#  'foxnews': 449,
#  'endthelockdown': 441,
#  'lockdown': 431,
#  'scamdemic': 420,
#  'billgatesisevil': 413,
#  'crimesagainsthumanity': 399,
#  'vaccine': 398,
#  'jailgates': 379,
#  'arrestfauci': 359,
#  'deepstate': 355,
#  'donaldtrump': 355,
#  'covidiots': 354,
#  'masksoff': 354,
#  'qanon': 353,
#  'anthonyfauci': 351,
#  'nomasks': 349,
#  'drfauci': 348,
#  'covidhoax': 335,
#  'covidー19': 322,
#  'kag': 316,
#  'thegreatawakening': 316,
#  'arresttrudeau': 315,
#  'masks': 312,
#  'cnn': 293,
#  'covid2019': 289,
#  'maga2020': 289,
#  'endtheshutdown': 286,
#  'openamerica': 285,
#  'billgatesbioterrorist': 285,
#  'bigpharma': 284,
#  'wakeupamerica': 266,
#  'covid1984': 260,
#  'masksoffamerica': 254,
#  'usa': 250,
#  'fraudfauci': 250,
#  'event201': 249,
#  'billgatesvirus': 241,
#  'china': 224,
#  'gatesfoundation': 223,
#  'news': 220,
#  'exposebillgates': 214,
#  'msnbc': 213,
#  'chinavirus': 205,
#  'reopenamericanow': 204,
#  'bbc': 204,
#  'hcq': 203,
#  'wakeup': 199,
#  'masksdontwork': 194,
#  'arrestmichaelryan': 192,
#  'biden': 191,
#  'agenda21': 189,
#  'trumpisaloser': 187,
#  'fauciliedpeopledied': 185,
#  'firewray': 184,
#  'quarantine': 184,
#  'openupamerica': 184,
#  'impeachbiden': 181,
#  'pandemic': 180,
#  'qanons': 177,
#  'fakenewsmedia': 175,
#  'fakescience': 172,
#  'firefaucihireshiva': 171,
#  'msm': 170,
#  'coronavirususa': 169,
#  'hcqworks': 165,
#  'fear': 164,
#  'savethechildren': 163,
#  'nwo': 162,
#  'ccpvirus': 162,
#  'firetrumpnotfauci': 162,
#  'filmyourhospital': 161,
#  'id2020': 159,
#  'savefauci': 156,
#  'shutdown': 155,
#  'firecdc': 154,
#  'fraud': 154,
#  'endthefed': 153,
#  'constitutionovercoronavirus': 153,
#  'covid__19': 150,
#  'americafirst': 150,
#  'mondaymotivaton': 147,
#  'fda': 147,
#  'freedom': 146,
#  'faucilied': 145,
#  'nomoremasks': 142,
#  'potus': 141,
#  'wethepeople': 140,
#  'laborlaws': 140,
#  'curfew': 140,
#  'coronaviruspandemic': 139,
#  'novaccineforme': 138,
#  'joebiden': 138,
#  'kag2020': 137,
#  'barexams': 136,
#  'greatawakening': 131,
#  'fuckfauci': 129,
#  'day18oflockdown': 128,
#  'sealhisfate': 128,
#  'fauciisafraud': 126,
#  'mondaythoughts': 124,
#  'hireshiva': 121,
#  'obamaknew': 120,
#  'hiremikovits': 120,
#  'democratsaredestroyingamerica': 120,
#  'deepstateexposed': 119,
#  'corona': 117,
#  'q': 117,
#  'jailgatesnow': 116,
#  'followthemoney': 115,
#  'truth': 115,
#  'corruption': 113,
#  'recallgavinnewsom': 113,
#  'bmgf': 113,
#  'fraudci': 112,
#  'coronavirusupdate': 111,
#  'arrestgates': 111,
#  'cv19': 110,
#  'treason': 109,
#  'truthfreedomhealth': 109,
#  'tuesdayvibe': 109,
#  'lockdowns': 108,
#  '5g': 108,
#  'plandemic2020': 108,
#  'military': 107,
#  'nih': 107,
#  'firemeghanmccain': 107,
#  'subpoenaobama': 106,
#  'pride2020': 105,
#  'science': 104,
#  'investigatefauci': 104,
#  'breaking': 102,
#  'democrats': 101,
#  'investigatebillgates': 101,
#  'fallguysseason4': 100,
#  'arrestlorilightfoot': 99,
#  'endthelockdowns': 98,
#  'wwg1wgaworldwide': 98,
#  'birx': 97,
#  'nonewnormal': 97,
#  'herdimmunity': 97,
#  'gates': 96,
#  'novaccine': 96,
#  'america': 96,
#  'defundwho': 96,
#  'billgatesevil': 94,
#  'scams': 94,
#  'bidencrimefamilly': 93,
#  'wuhanvirus': 93,
#  'chinesevirus': 92,
#  'firebrix': 91,
#  'vaccineagenda': 90,
#  'smartnews': 90,
#  'saynotobillgates': 90,
#  'coronagate': 89,
#  'election2020': 89,
#  'gatesforprison2020': 89,
#  'enoughisenough': 89,
#  'gatesofhell': 89,
#  'socialdistancing': 88,
#  'magats': 88,
#  'faucihero': 87,
#  'trump2020nowmorethanever': 87,
#  'covidlie': 87,
#  'defundcdc': 87,
#  'obama': 87,
#  '1donlineconcertstayathome': 87,
#  'alexjones': 86,
#  'emptyhospitals': 85,
#  'coronavirushoax': 84,
#  'chinaliedpeopledied': 83,
#  'breakingnews': 83,
#  'shiva4senate': 83,
#  'mwn': 83,
#  'trumpvirus': 83,
#  'impeachdewine': 83,
#  'obey': 82,
#  'billgatesisnotourfriend': 82,
#  'wuhan': 82,
#  'infowars': 82,
#  'gavinnewsome': 81,
#  'fakenewsalert': 81,
#  'checkthestats': 80,
#  'health': 80,
#  'gavinhuntmustgo': 79,
#  'remdesivir': 79,
#  'trump2020landslide': 79,
#  'democratshateamerica': 79,
#  'scamdemic2020': 79,
#  'vote': 79,
#  'bidenbordercrisis': 79,
#  'maskoff': 78,
#  'attorneys': 78,
#  'coronawillendsoon': 78,
#  'trumpmeltdown': 77,
#  'mondaymotivation': 77,
#  'openeconomy': 76,
#  'opentheeconomy': 75,
#  'foh': 75,
#  'bordercrisis': 75,
#  'stimuluschecks': 74,
#  'kungflu': 74,
#  'eastermonday': 74,
#  'opencalifornia': 73,
#  'markofthebeast': 73,
#  'deepstatefauci': 73,
#  'stimulusdeposit': 72,
#  'bootbirx': 72,
#  'walkaway': 72,
#  'indictfauci': 72,
#  'qarmy': 70,
#  'trumpnowmorethanever': 70,
#  'mondaymood': 70,
#  'buildthewall': 69,
#  'liberalismisamentaldisorder': 69,
#  'freealexjones': 69,
#  'florida': 69,
#  'maskup': 69,
#  'bestpresidentever': 69,
#  'oann': 69,
#  'freeinfowars': 68,
#  'impeachbidennow': 68,
#  'gregreese': 67,
#  'cbs': 67,
#  'agenda2030': 67,
#  'warroompandemic': 66,
#  'lockdownend': 66,
#  'covidiot': 66,
#  'nnevyy': 66,
#  'ccp': 66,
#  'trumppressbriefing': 66,
#  'flipflopfauci': 66,
#  'alllivesmatter': 66,
#  'nomask': 66,
#  'firefaucci': 66,
#  'maskdeception': 66,
#  'blm': 65,
#  'freedomoverfear': 65,
#  'firefaucibootbirx': 65,
#  'un': 64,
#  'california': 64,
#  'stayhome': 64,
#  'wedonotconsent': 64,
#  'fuckbillgates': 63,
#  'psyop': 63,
#  'hydroxychloriquine': 63,
#  'debunkthisfauci': 63,
#  'sarscov2': 63,
#  'mkultra': 62,
#  'novaccinepassports': 62,
#  'faucivirus': 62,
#  'medicalfraud': 61,
#  'drainthedeepstateswamp': 61,
#  'uk': 61,
#  'nbc': 61,
#  'gatesgate': 61,
#  'wuhanlab': 61,
#  'thegreatawakeningworldwide': 61,
#  'pizzagate': 61,
#  'filmyourhospitals': 61,
#  'tyranny': 61,
#  'chromatica': 60,
#  'arresttedros': 60,
#  'insecurehbo': 60,
#  'endthelockdownnow': 60,
#  'covidvaccine': 60,
#  'makeamericahealthyagain': 60,
#  'patriotsunited': 60,
#  'keepfauci': 59,
#  'yoga': 59,
#  'theview': 59,
#  'gainoffunction': 58,
#  'obamakneweverything': 58,
#  'enemyofthepeople': 58,
#  'jailfauci': 58,
#  'operationgridlock': 58,
#  'coronavirustruth': 58,
#  'covididiots': 57,
#  'abc': 57,
#  'stayathome': 57,
#  'virus': 56,
#  'faucilies': 56,
#  'wholiedpeopledied': 56,
#  'jailbillgates': 56,
#  'hydroxycloroquine': 56,
#  'firecavuto': 56,
#  'impeachharris': 56,
#  'gop': 55,
#  'congress': 55,
#  'firetam': 55,
#  'recallgavin2020': 55,
#  'reopencalifornia': 55,
#  'blacklivesmatter': 54,
#  'hoax': 54,
#  'bidenknew': 53,
#  'vaccinesaregenocide': 53,
#  'neverbiden': 53,
#  'coronavirusupdates': 52,
#  'factsmatter': 52,
#  'americans': 52,
#  'presidenttrump': 52,
#  'fakefauci': 52,
#  'endlockdown': 52,
#  'lockdownrebellion': 52,
#  'stockmarket': 51,
#  'truthmatters': 51,
#  'zelenkoprotocol': 51,
#  'gatesvirus': 51,
#  'borisjohnson': 51,
#  'puppetpresident': 51,
#  'drshiva': 51,
#  'realdonaldtrump': 51,
#  'greatreset': 50,
#  'wwg1gwa': 50,
#  'idiotbiden': 50,
#  'fire': 50,
#  'aids': 50,
#  'deepstatetakedown': 50,
#  'lockhimup': 50,
#  'lyingpos': 49,
#  'hailtothethief': 49,
#  'politics': 49,
#  'us': 48,
#  'chinaliedandpeopledied': 48,
#  'bidenwilineverbepresident': 48,
#  'controlavirus': 48,
#  'fearmongering': 48,
#  'nyc': 48,
#  'wearethenewsnow': 48,
#  'trump2020landslidevictory': 48,
#  'ivermectin': 48,
#  'fauciisaliar': 48,
#  'chrispinto': 47,
#  'texas': 47,
#  'noiseofthunder': 47,
#  'drjudymikovits': 47,
#  'lawyers': 47,
#  'lockdown2': 47,
#  'novaccinepassportsanywhere': 47,
#  'stopthemadness': 46,
#  'liberty': 46,
#  'politicalfraud': 46,
#  'hiv': 46,
#  'unmaskamerica': 46,
#  'wearealljulianassange': 46,
#  'vaccinesarenottheanswer': 46,
#  'democratsarecorrupt': 46,
#  'drainthedeepstateluciferiancabal': 46,
#  'drshivaayyadurai': 45,
#  'faucism': 45,
#  'saveamerica': 45,
#  'homelandsecurity': 45,
#  'facts': 44,
#  'mandatoryvaccinations': 44,
#  'patriots': 44,
#  'coronavirusoutbreak': 44,
#  'wewillnotcomply': 44,
#  'firekushner': 44,
#  'surgicalmask': 44,
#  'soros': 44,
#  'voterfraud': 44,
#  'ladygaga': 43,
#  'plannedemic': 43,
#  'openupamericanow': 43,
#  'ntsiki': 43,
#  'scientist': 43,
#  'nomorelockdowns': 43,
#  'flattenthecurve': 43,
#  'lockdownskill': 43,
#  'judymikovits': 43,
#  'democratstheenemywithin': 43,
#  'newyork': 43,
#  'senatehearing': 42,
#  'peternavarro': 42,
#  'labourleaks': 42,
#  'n3': 42,
#  'fauciouchie': 41,
#  'policestate': 41,
#  'medicalfreedom': 41,
#  '5gcoronavirus': 41,
#  'voteredtosaveamerica': 40,
#  'republicans': 40,
#  'recallwhitmer': 40,
#  'defundthewho': 40,
#  'bbb21': 39,
#  'ccpliedpeopledied': 39,
#  'psyops': 39,
#  'goodbyegates': 39,
#  'drbirx': 39,
#  'backtoworkamerica': 39,
#  'lockherup': 39,
#  'fightforfreedom': 39,
#  'hannity': 39,
#  'liberateminnesota': 39,
#  'arrestgeorgesoros': 38,
#  'trumpburialpits': 38,
#  'share': 38,
#  'nancypelosi': 38,
#  'fakenewsenemyofthepeople': 38,
#  'tucker': 38,
#  'trumpliespeopledie': 38,
#  'pfizer': 38,
#  'coronavirusvaccine': 38,
#  'stopbillgates': 38,
#  'maskingchildrenischildabuse': 38,
#  'stfugates': 38,
#  'niaid': 38,
#  'lies': 38,
#  'beijingbiden': 38,
#  'plagueofcorruption': 38,
#  'executiveorder': 38,
#  'crimesagainstchildren': 37,
#  'trumpliesamericansdie': 37,
#  'hcqworksfauciknewin2005': 37,
#  'economy': 37,
#  'liberatemichigan': 37,
#  'mask': 37,
#  'and': 37,
#  'lockupfauci': 37,
#  'freeamerica': 37,
#  'prosecutegates': 37,
#  'epsteindidntkillhimself': 37,
#  'tuesdayvibes': 37,
#  'pelosi': 37,
#  'voteredtosaveamerica2020': 37,
#  'hcqw0rks': 37,
#  'uscoastguard': 37,
#  'flynnwasframed': 37,
#  'keepamericagreat': 36,
#  'jesussaves': 36,
#  'liarfauci': 36,
#  'ingrahamangle': 36,
#  'liar': 36,
#  'censorship': 35,
#  'noessential': 35,
#  'sheeple': 35,
#  'fightback': 35,
#  'trumptrain': 35,
#  'drbuttar': 35,
#  'backinbusiness': 35,
#  'billofrights': 35,
#  'weareopen': 35,
#  'notmyvirus': 35,
#  'biden2020': 35,
#  'maskoffmn': 35,
#  'resist': 35,
#  'india': 35,
#  'bidendementia': 35,
#  'walkawayfromdemocrats': 35,
#  'watch': 35,
#  'backtowork': 34,
#  'socialismkills': 34,
#  'riseup': 34,
#  'idonotconsent': 34,
#  'hydroxychloroquineworks': 34,
#  'openminnesota': 34,
#  'donoharm': 34,
#  'bebrave': 34,
#  'nowalz': 34,
#  'plandemicdocumentary': 34,
#  'arrestbillgates2020': 34,
#  'topbuzz': 34,
#  'jesuschrist': 34,
#  'fauciforprison': 34,
#  'endlockdownnow': 34,
#  'newsmax': 34,
#  'twitter': 33,
#  'genocide': 33,
#  'seattle': 33,
#  'comeyknew': 33,
#  'dictatortrump': 33,
#  'now': 33,
#  'mondaymorning': 33,
#  'whitehouse': 33,
#  'sundaythoughts': 33,
#  'firehaspel': 33,
#  'newworldorder': 33,
#  'cuomo': 33,
#  '2020election': 33,
#  'trumppressconf': 32,
#  'convid': 32,
#  'wallstreetjournal': 32,
#  'senate': 32,
#  'qblueskyq': 32,
#  'firecuomo': 32,
#  'reopen': 32,
#  'cuomokilledgrandma': 32,
#  'firegates': 32,
#  'constitution': 32,
#  'woke': 32,
#  'firebillgates': 32,
#  'livingnotlockdown': 32,
#  'wtf': 32,
#  'maga2020landslide': 32,
#  'backtonormal': 32,
#  'canada': 31,
#  'firefauchi': 31,
#  'trumpownseverydeath': 31,
#  'subpoenabiden': 31,
#  'covidisover': 31,
#  'dems': 31,
#  'lockdownscostlives': 31,
#  'killary': 31,
#  'investigategates': 31,
#  'scamdemic2021': 31,
#  'godwins': 31,
#  'depopulationagenda': 31,
#  'opencalifornianow': 31,
#  'covid1948': 31,
#  'firewho': 31,
#  'getbacktowork': 31,
#  'chloroquine': 31,
#  'russia': 30,
#  'thegreatreset': 30,
#  'globalists': 30,
#  'stoptyranny': 30,
#  'oustthewho': 30,
#  'medicalscams': 30,
#  'whereshunter': 30,
#  'freepa': 30,
#  'recallnewsom': 30,
#  '2a': 30,
#  'taylorswift': 30,
#  'masks4all': 30,
#  'deepstatecabal': 30,
#  'wuhancoronavirus': 30,
#  'bidenharris': 30,
#  'firepelosi': 30,
#  'tcot': 30,
#  'cuomoliedpeopledied': 30,
#  'propaganda': 29,
#  'firingfauci': 29,
#  'eugenics': 29,
#  'covidisfake': 29,
#  'tuesdaymotivation': 29,
#  'vaccineispoison': 29,
#  'trudeaumustgo': 29,
#  'potustrump': 29,
#  'hillaryclinton': 29,
#  'flu': 29,
#  'coronavirusliar': 29,
#  'beastsystem': 29,
#  'reopenschools': 29,
#  'novaccines': 29,
#  'expelmaxinewater': 29,
#  'liberateohio': 29,
#  'constitutionalrights': 29,
#  'moderna': 28,
#  'obamagates': 28,
#  'ronjohnson': 28,
#  'democrat': 28,
#  'dumptrump': 28,
#  'quarantinediaries': 28,
#  'kingtrump': 28,
#  'factsnotfear': 28,
#  'bengazi': 28,
#  'endtheshutdownnow': 28,
#  'joebidenisaracist': 28,
#  'defundun': 28,
#  'coronavaccine': 28,
#  'davos21': 28,
#  'africa': 28,
#  'stopthesteal': 28,
#  'firedrfauci': 28,
#  'repost': 28,
#  'thefive': 28,
#  'bidencrimefamily': 28,
#  'killercuomo': 28,
#  'firebiden': 28,
#  '4moreyears': 28,
#  'endtimes': 27,
#  'unsealepstein': 27,
#  'contacttracing': 27,
#  'adrenachrome': 27,
#  'liberalismistherealpandemic': 27,
#  'johnkerryisatraitor': 27,
#  'cooking': 27,
#  'atmche': 27,
#  'immunesystem': 27,
#  'asheepnomore': 27,
#  'imf': 27,
#  'firebarr': 27,
#  'marines': 27,
#  'msmistheenemyofthepeople': 27,
#  'darktolight': 27,
#  'boycottcocacola': 27,
#  'riots': 27,
#  'civilliberties': 27,
#  'randpaul': 27,
#  'schools': 26,
#  'mybodymychoice': 26,
#  'bobby': 26,
#  'faucimustgo': 26,
#  'schiffknew': 26,
#  'bidenwillneverbepresident': 26,
#  'stoplockdown': 26,
#  'brennanknew': 26,
#  'pedowood': 26,
#  'debforinterior': 26,
#  'hydroxycholoroquine': 26,
#  'liberateamerica': 26,
#  'winmetawin': 26,
#  'tuckercarlson': 26,
#  'clintonemailscandal': 26,
#  'unsealjfk': 26,
#  'clintoncrimefamily': 26,
#  'reopenschoolsnow': 26,
#  'obamamusttestify': 26,
#  'notobillgates': 26,
#  'ethiopia': 25,
#  'mileycyrus': 25,
#  'bigtech': 25,
#  'globalist': 25,
#  'godblessamerica': 25,
#  'wearamask': 25,
#  'fauxci': 25,
#  'lockupneilferguson': 25,
#  'jihyo': 25,
#  'pharmafauci': 25,
#  'adrenochrome': 25,
#  'notonwo': 25,
#  'arrestwho': 25,
#  'obamagategate': 25,
#  'italy': 25,
#  'impeachpelosi': 25,
#  'traitor': 25,
#  'fakevirus': 25,
#  'wallstreet': 25,
#  'trending': 24,
#  'jailfortedros': 24,
#  'boycottmlb': 24,
#  'joebidenisarapist': 24,
#  'cancelculture': 24,
#  'fireferrer': 24,
#  'booking': 24,
#  'vaccineisdeath': 24,
#  'molonlabe': 24,
#  'covidvaccinevictims': 24,
#  'arrestbirx': 24,
#  'nypost': 24,
#  'nobodyneededtodie': 24,
#  'bidenharris2020': 23,
#  'arrestborisjohnson': 23,
#  'nomaskmandates': 23,
#  'god': 23,
#  'backtheblue': 23,
#  'faucigate': 23,
#  'durhamindictments': 23,
#  'mkultramindcontrol': 23,
#  'gitmo': 23,
#  'bidencorruption': 23,
#  'firewilma': 23,
#  'trusttheplan': 23,
#  'trumpgenocide': 23,
#  'toronto': 23,
#  'covid19hoax': 23,
#  'voteridnow': 23,
#  'gavinnewsom': 23,
#  'trumpcrimefamily': 23,
#  'qanon2020': 23,
#  'burnthemask': 23,
#  'fauciliespeopledie': 23,
#  'hr6666': 23,
#  'fauciknew': 23,
#  'biblereading': 23,
#  'twintowers': 22,
#  'michigan': 22,
#  'woodward': 22,
#  'impeachwolf': 22,
#  'gsk': 22,
#  'voting': 22,
#  'killerfauci': 22,
#  'doctors': 22,
#  'abcnews': 22,
#  'prosecutefauci': 22,
#  'stopthecdc': 22,
#  'sheepnomore': 22,
#  'nurses': 22,
#  'jesus': 22,
#  'drfauciisanationalhero': 22,
#  'backtoworknow': 22,
#  'firefroggie': 22,
#  'wrestlemania': 22,
#  'sciencematters': 22,
#  'trumpwon': 22,
#  'justsayno': 22,
#  'gannett': 22,
#  'donaldjtrump': 21,
#  'youtube': 21,
#  'trumpliedpeopledied': 21,
#  'facemasks': 21,
#  'vaccinepassports': 21,
#  'popefauci': 21,
#  'defundthecdc': 21,
#  'famine': 21,
#  'openthecountry': 21,
#  'covidfraud': 21,
#  'lockupgates': 21,
#  'thursdaythoughts': 21,
#  'kag2020landslidevictory': 21,
#  'arrestcuomo': 21,
#  'cdcall50': 21,
#  'jobs': 21,
#  'microchip': 21,
#  'australia': 21,
#  'billgatesisnotadoctor': 21,
#  'informedconsent': 21,
#  'siayaburial': 21,
#  'poison': 21,
#  'tigerwoods': 21,
#  'newwho195': 21,
#  'trumppandemic': 21,
#  'obamagaate': 21,
#  'investigate': 21,
#  'vaccination': 21,
#  'bidenlied': 21,
#  'cuckoovirus': 21,
#  'falseflag': 21,
#  'art': 21,
#  'impeachbidenharris': 21,
#  'vaxxed': 21,
#  'tedros': 21,
#  'covidrelief': 21,
#  'rajputboy': 21,
#  'civildisobedience': 20,
#  'fakenewscnn': 20,
#  'medicaltyranny': 20,
#  'openourcountry': 20,
#  'thursdayvibes': 20,
#  'cdccorruption': 20,
#  'boycottdelta': 20,
#  'zinc': 20,
#  'scam': 20,
#  'meghanmccain': 20,
#  'opennj': 20,
#  'periscope': 20,
#  'american': 20,
#  'lockdownextension': 20,
#  'thursdaymorning': 20,
#  'stacksats': 20,
#  'pressbriefing': 20,
#  'reopennc': 20,
#  'vaccinated': 20,
#  'donttreadonme': 20,
#  'operationwarpspeed': 20,
#  'investigations': 20,
#  'depopulation': 20,
#  'fireamyacton': 20,
#  'tuesdaythoughts': 20,
#  'berniesanders': 20,
#  'college': 20,
#  'populationcontrol': 20,
#  'restarttheeconomy': 20,
#  'hunterbiden': 20,
#  'vitamind': 20,
#  'termlimits': 20,
#  'fridayvibes': 20,
#  'humantrafficking': 20,
#  'ballotharvesting': 20,
#  'martiallaw': 20,
#  'endlockdowns': 20,
#  'freespeech': 19,
#  'stop5g': 19,
#  'bts': 19,
#  'wwg1wga_worldwide': 19,
#  'dodocode': 19,
#  'biglie': 19,
#  '25thamendmentnow': 19,
#  'testing': 19,
#  'rosmello': 19,
#  'knowingly': 19,
#  'mexico': 19,
#  'boycottchina': 19,
#  'lockdowneffect': 19,
#  'drainthedeepstate': 19,
#  'chinamustpay': 19,
#  'govgavinnewsom': 19,
#  'liberatenewhampshire': 19,
#  'trumpistheworstpresidentever': 19,
#  'rockefellers': 19,
#  'hr1': 19,
#  'racism': 19,
#  'gavi': 19,
#  'covid19vaccine': 19,
#  'terrorism': 19,
#  'gyms': 19,
#  'linkedin': 19,
#  'endcdc': 19,
#  'hiremikovitz': 19,
#  'neverforgetbenghazi': 19,
#  'cult45': 18,
#  'mikovits': 18,
#  'cdclies': 18,
#  'dropoutbiden': 18,
#  'reopenourschools': 18,
#  'mlb': 18,
#  'unmask': 18,
#  'superspreader': 18,
#  'hiredrshiva': 18,
#  'blacktwitter': 18,
#  'fireacton': 18,
#  'pilltry': 18,
#  'bitcoin': 18,
#  'exposefauci': 18,
#  'look_apink_is_back': 18,
#  'today': 18,
#  'h1n1': 18,
#  'israel': 18,
#  'freedomofspeech': 18,
#  'bioweapon': 18,
#  'impeachwhitmer': 18,
#  'covidisafraudonamerica': 18,
#  'phonyfauci': 18,
#  'fauciisahero': 18,
#  'fauxfauci': 18,
#  'bluelivesmatter': 18,
#  'hoaxvirus': 18,
#  'publichealth': 18,
#  'bioweapons': 18,
#  'bitchute': 18,
#  'fourmoreyears': 18,
#  'defundnih': 18,
#  'donotconcede': 18,
#  'pillnyc': 18,
#  'microchipped': 18,
#  'wwg1wwga': 18,
#  'btc': 18,
#  'essentialsocialsecurity': 18,
#  'informed': 18,
#  'quotes': 18,
#  'impeachcuomo': 18,
#  'nomandatoryvaccines': 18,
#  'letsgetbacktowork': 18,
#  'lancetgate': 18,
#  'covid19pandemic': 18,
#  'cia': 18,
#  'design': 18,
#  'sheep': 18,
#  'andrewcuomo': 18,
#  'faketests': 18,
#  'conflictofinterest': 18,
#  'benghazi': 18,
#  'ohio': 17,
#  'sweden': 17,
#  'openamericaagain': 17,
#  'fake': 17,
#  'vaccinatebillgates': 17,
#  'stopthedeepstate': 17,
#  'gatesisevil': 17,
#  'bidenspied': 17,
#  'firepsaki': 17,
#  'epstein': 17,
#  'wewerebothyoung': 17,
#  'lufc': 17,
#  'thestormishere': 17,
#  'cdcfraud': 17,
#  'flyer': 17,
#  'fbi': 17,
#  'cdcwhistleblower': 17,
#  'hydroxychloroquineandazithromycin': 17,
#  'tedrosadhanom': 17,
#  'nomandatoryvaccine': 17,
#  'coronaoutbreak': 17,
#  'saynotovaccine': 17,
#  'vaccineskill': 17,
#  'sars_cov_2': 17,
#  'covid19usa': 17,
#  'fearporn': 17,
#  'stopthefearmongering': 17,
#  'conspiracy': 17,
#  'billboardincludethe10k': 17,
#  'makeamericagreatagain': 17,
#  'socialism': 17,
#  'takeouttuesday': 17,
#  'fauciwasfunding': 17,
#  'morningjoe': 17,
#  'agenda': 17,
#  'impeachaoc': 17,
#  'livefreebreathefree': 17,
#  'protectfauci': 17,
#  'quarantinelife': 16,
#  'hypocrisy': 16,
#  'vaccineswork': 16,
#  'แดดดี้ที่ไม่ได้แปลว่าพ่อ': 16,
#  'deborahbirx': 16,
#  'biochemistry': 16,
#  'killbill': 16,
#  'draintheswamp2020': 16,
#  'ftdietrick': 16,
#  'cuomocoverup': 16,
#  'nomore': 16,
#  'love': 16,
#  'trumppressconference': 16,
#  'voterid': 16,
#  'reopennj': 16,
#  'death': 16,
#  'cashapp': 16,
#  'crookedjoebiden': 16,
#  'impeachiihanomar': 16,
#  'saynobillgates': 16,
#  'maga2020landslidevictory': 16,
#  'control': 16,
#  'liberate': 16,
#  'georgefloyd': 16,
#  'coronaviruslockdown': 16,
#  'fortnite': 16,
#  'lockthemup': 16,
#  'photography': 16,
#  'medtwitter': 16,
#  'civilunrest': 16,
#  'education': 16,
#  'firewraytoday': 16,
#  'nhs': 16,
#  'quack': 16,
#  'dontfirefauci': 16,
#  'trumppence2020': 16,
#  'firejaredkushner': 16,
#  'liberatevirginia': 16,
#  'obamagateworldwide': 16,
#  'trumprally': 16,
#  'maskssavelives': 16,
#  'dumptrump2020': 16,
#  'logo': 16,
#  'covipass': 16,
#  'stopgates': 16,
#  'thegreatdepression': 16,
#  'music': 16,
#  'hope': 16,
#  'naziscientist': 16,
#  'covidlies': 16,
#  'openschools': 16,
#  'yourefired': 16,
#  'faucisucks': 16,
#  'uprootthefraud': 15,
#  'unconstitutional': 15,
#  'drainingtheswamp': 15,
#  'swineflu': 15,
#  'wearetherevolution': 15,
#  'coronvirus': 15,
#  'fliptheswitch': 15,
#  'vaccineinjury': 15,
#  'timstwitterlisteningparty': 15,
#  'gematria': 15,
#  'vaccinatewilfred': 15,
#  'trendingnow': 15,
#  'الهلال_النصر': 15,
#  'worstpresidentinhistory': 15,
#  'openborders': 15,
#  'media': 15,
#  'evil': 15,
#  'climatechange': 15,
#  'trumpcult': 15,
#  'hirefauci': 15,
#  'faucianbargain': 15,
#  'plandemichoax': 15,
#  'qanonworldwide': 15,
#  'stocks': 15,
#  'iphone13': 15,
#  'msmfakenews': 15,
#  'rendering': 15,
#  'antifa': 15,
#  'fiverr': 15,
#  'buythedip': 15,
#  'tds': 15,
#  'sleepyjoe': 15,
#  'idiots': 15,
#  'resistance': 15,
#  'digitalmarketing': 15,
#  'foragizelly': 15,
#  'georgia': 15,
#  'arresthancock': 15,
#  ...}
